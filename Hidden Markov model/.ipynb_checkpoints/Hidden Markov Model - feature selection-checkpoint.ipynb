# %%
# import neccessary library
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.impute import KNNImputer 
from sklearn.feature_selection import RFE, SelectKBest, f_classif
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.linear_model import LinearRegression
import os 
import warnings
warnings.filterwarnings('ignore')

# %%
# Extracting Data from a Single Excel File Containing Multiple Stock Index Information
def data_cleaning(original_file_name, saved_file_name):
    index_data_dir = os.path.join(os.getcwd(), 'data', 'feature_data', 'unfinish data')
    original_file = pd.read_excel(os.path.join(index_data_dir, original_file_name))

    # Secid: [RUT:102434 DJX: 102456 SPX: 108105]
    filtered_data = original_file[original_file['Security ID'] == 102434]
    filtered_data['The Date of this Option Price'] = filtered_data['The Date of this Option Price'].dt.strftime('%-d/%-m/%Y')

    # Define the path for the new Excel file
    output_excel_path = os.path.join(index_data_dir, saved_file_name)

    # Write the filtered data to a new Excel file
    filtered_data.to_excel(output_excel_path, index=False)

# %%
#data_cleaning('OptionMetrics - Standardized Options.xlsx', 'OptionMetrics - RUT Standardized Options.xlsx')

# %%
def data_clearning_for_option(original_file_name, saved_file_name):
    index_data_dir = os.path.join(os.getcwd(), 'data', 'feature_data', 'unfinish data')
    original_file = pd.read_excel(os.path.join(index_data_dir, original_file_name))
    
    # C=Call, P=Put ID
    filtered_data = original_file[original_file['C=Call, P=Put'] == 'P']

    # Define the path for the new Excel file
    output_excel_path = os.path.join(index_data_dir, saved_file_name)
    
    # Write the filtered data to a new Excel file
    filtered_data.to_excel(output_excel_path, index=False)

# %%
#data_clearning_for_option('OptionMetrics - RUT Standardized Options.xlsx', 'OptionMetrics - RUT Standardized Options (PUT).xlsx')

# %%
# Avoid data leakage to test data
# Impute missing data in train and test datasets using KNNImputer.
def impute_data(train, test):
    imputer = KNNImputer(n_neighbors=5)

    # Fit the imputer on the training data
    imputer.fit(train)

    # Transform both training and testing data
    train_imputed = imputer.transform(train)
    test_imputed = imputer.transform(test)

    return train_imputed, test_imputed

# get the feature data from data folder
def load_feature_data(start_date, test_start_dates, end_date, rebal_period):
    # Load index data, impute missing values and return train and test datasets
    index_data_dir = os.path.join(os.getcwd(), 'data', 'feature_data')
    result_train_df = pd.DataFrame()
    result_test_df = pd.DataFrame()
    
    index_data_name_file = {
        'CBOE DJIA Volatility Index':'CBOE DJIA Volatility Index - Close.xlsx',
        'CBOE NASDAQ Volatility Index': 'CBOE NASDAQ Volatility Index - Close.xlsx',
        'CBOE S&P100 Volatility Index': 'CBOE S&P100 Volatility Index - Close.xlsx',
        'CBOE S&P500 Volatility Index': 'CBOE S&P500 Volatility Index - Close.xlsx',
        'OptionMetrics - DJI Historical Volatility': 'OptionMetrics - DJI Historical Volatility.xlsx',
        'OptionMetrics - Russell 2000 Historical Volatility': 'OptionMetrics - Russell 2000 Historical Volatility.xlsx',
        'OptionMetrics - SPX Historical Volatility': 'OptionMetrics - SPX Historical Volatility.xlsx',
        'OptionMetrics - DJX  Index Dividend Yield': 'OptionMetrics - DJX  Index Dividend Yield.xlsx',
        'OptionMetrics - Russell 2000  Index Dividend Yield': 'OptionMetrics - Russell 2000  Index Dividend Yield.xlsx',
        'OptionMetrics - SPX  Index Dividend Yield': 'OptionMetrics - SPX  Index Dividend Yield.xlsx',
        'OptionMetrics - Russel 2000 The total contract open interest': 'OptionMetrics - Russel 2000 The total contract open interest.xlsx',
        'OptionMetrics - Russel 2000 Option Volume': 'OptionMetrics - Russel 2000 Option Volume.xlsx',
        'OptionMetrics - DJX Option Volume': 'OptionMetrics - DJX Option Volume.xlsx',
        'OptionMetrics - DJX The total contract open interest': 'OptionMetrics - DJX The total contract open interest.xlsx',
        'OptionMetrics - SPX Option Volume': 'OptionMetrics - SPX Option Volume.xlsx',
        'OptionMetrics - SPX The total contract open interest': 'OptionMetrics - SPX The total contract open interest.xlsx',
        'OptionMetrics - DJX Calculated Price for the Underlying Security on the Exp. Date (CALL)': 'OptionMetrics - DJX Calculated Price for the Underlying Security on the Exp. Date (CALL).xlsx',
        'OptionMetrics - DJX Delta of the Option(CALL)': 'OptionMetrics - DJX Delta of the Option(CALL).xlsx',
        'OptionMetrics - DJX Implied Volatility of the Option(CALL)': 'OptionMetrics - DJX Implied Volatility of the Option(CALL).xlsx',
        'OptionMetrics - DJX Interpolated Premium for the Option(CALL)': 'OptionMetrics - DJX Interpolated Premium for the Option(CALL).xlsx',
        'OptionMetrics - DJX Strike Price, Currently Always Equal to Forward Price(CALL)': 'OptionMetrics - DJX Strike Price, Currently Always Equal to Forward Price(CALL).xlsx',
        'OptionMetrics - DJX Theta of the Option(CALL)': 'OptionMetrics - DJX Theta of the Option(CALL).xlsx',
        'OptionMetrics - DJX VegaKappa of the Option(CALL)': 'OptionMetrics - DJX VegaKappa of the Option(CALL).xlsx',
        'OptionMetrics - Zero Coupon Yield Curve': 'OptionMetrics - Zero Coupon Yield Curve.xlsx',
        'OptionMetrics - DJX Calculated Price for the Underlying Security on the Exp. Date (PUT).xlsx': 'OptionMetrics - DJX Calculated Price for the Underlying Security on the Exp. Date (PUT).xlsx',
        'OptionMetrics - DJX Delta of the Option (PUT)': 'OptionMetrics - DJX Delta of the Option (PUT).xlsx',
        'OptionMetrics - DJX Gamma of the Option (PUT)': 'OptionMetrics - DJX Gamma of the Option (PUT).xlsx',
        'OptionMetrics - DJX Interpolated Premium for the Option (PUT)': 'OptionMetrics - DJX Interpolated Premium for the Option (PUT).xlsx',
        'OptionMetrics - DJX Strike Price, Currently Always Equal to Forward Price (PUT)': 'OptionMetrics - DJX Strike Price, Currently Always Equal to Forward Price (PUT).xlsx',
        'OptionMetrics - DJX Theta of the Option (PUT)': 'OptionMetrics - DJX Theta of the Option (PUT).xlsx',
        'OptionMetrics - DJX VegaKappa of the Option (PUT)': 'OptionMetrics - DJX VegaKappa of the Option (PUT).xlsx',
        'OptionMetrics - Russell 2000 Calculated Price for the Underlying Security on the Exp. Date (CALL)': 'OptionMetrics - Russell 2000 Calculated Price for the Underlying Security on the Exp. Date (CALL).xlsx',
        'OptionMetrics - Russell 2000 Delta of the Option(CALL)': 'OptionMetrics - Russell 2000 Delta of the Option(CALL).xlsx',
        'OptionMetrics - Russell 2000 Gamma of the Option(CALL)': 'OptionMetrics - Russell 2000 Gamma of the Option(CALL).xlsx',
        'OptionMetrics - Russell 2000 Implied Volatility of the Option(CALL)': 'OptionMetrics - Russell 2000 Implied Volatility of the Option(CALL).xlsx',
        'OptionMetrics - Russell 2000 Interpolated Premium for the Option (CALL)': 'OptionMetrics - Russell 2000 Interpolated Premium for the Option (CALL).xlsx',
        'OptionMetrics - Russell 2000 Strike Price, Currently Always Equal to Forward Price (CALL)': 'OptionMetrics - Russell 2000 Strike Price, Currently Always Equal to Forward Price (CALL).xlsx',
        'OptionMetrics - Russell 2000 Theta of the Option(CALL)': 'OptionMetrics - Russell 2000 Theta of the Option(CALL).xlsx',
        'OptionMetrics - Russell 2000 VegaKappa of the Option(CALL)': 'OptionMetrics - Russell 2000 VegaKappa of the Option(CALL).xlsx',
        'OptionMetrics - Russell 2000 VegaKappa of the Option (PUT)': 'OptionMetrics - Russell 2000 VegaKappa of the Option (PUT).xlsx',
        'OptionMetrics - Russell 2000 Theta of the Option (PUT)': 'OptionMetrics - Russell 2000 Theta of the Option (PUT).xlsx',
        'OptionMetrics - Russell 2000 Gamma of the Option (PUT)': 'OptionMetrics - Russell 2000 Gamma of the Option (PUT).xlsx',
        'OptionMetrics - Russell 2000 Delta of the Option (PUT)': 'OptionMetrics - Russell 2000 Delta of the Option (PUT).xlsx',
        'OptionMetrics - Russell 2000 Implied Volatility of the Option (PUT)': 'OptionMetrics - Russell 2000 Implied Volatility of the Option (PUT).xlsx',
        'OptionMetrics - Russell 2000 Interpolated Premium for the Option (PUT)': 'OptionMetrics - Russell 2000 Interpolated Premium for the Option (PUT).xlsx',
        'OptionMetrics - Russell 2000 Strike Price, Currently Always Equal to Forward Price (PUT)': 'OptionMetrics - Russell 2000 Strike Price, Currently Always Equal to Forward Price (PUT).xlsx',
        'OptionMetrics - Russell 2000 Calculated Price for the Underlying Security on the Exp. Date (PUT)': 'OptionMetrics - Russell 2000 Calculated Price for the Underlying Security on the Exp. Date (PUT).xlsx',
        'OptionMetrics - SPX Calculated Price for the Underlying Security on the Exp. Date (CALL)': 'OptionMetrics - SPX Calculated Price for the Underlying Security on the Exp. Date (CALL).xlsx',
        'OptionMetrics - SPX Delta of the Option (CALL)': 'OptionMetrics - SPX Delta of the Option (CALL).xlsx',
        'OptionMetrics - SPX Gamma of the Option (CALL)': 'OptionMetrics - SPX Gamma of the Option (CALL).xlsx',
        'OptionMetrics - SPX Implied Volatility of the Option (CALL)': 'OptionMetrics - SPX Implied Volatility of the Option (CALL).xlsx',
        'OptionMetrics - SPX Interpolated Premium for the Option (CALL)': 'OptionMetrics - SPX Interpolated Premium for the Option (CALL).xlsx',
        'OptionMetrics - SPX Standardized Options (PUT)': 'OptionMetrics - SPX Standardized Options (PUT).xlsx',
        'OptionMetrics - SPX Strike Price, Currently Always Equal to Forward Price (CALL)': 'OptionMetrics - SPX Strike Price, Currently Always Equal to Forward Price (CALL).xlsx',
        'OptionMetrics - SPX Theta of the Option (CALL)': 'OptionMetrics - SPX Theta of the Option (CALL).xlsx',
        'OptionMetrics - SPX VegaKappa of the Option (PUT)': 'OptionMetrics - SPX VegaKappa of the Option (PUT).xlsx'
        
        
    }
    
    for ind_name in index_data_name_file.keys():
        try:
            input = pd.read_excel(os.path.join(index_data_dir, index_data_name_file[ind_name]), index_col='Date')
            # Ensure that the index is a DatetimeIndex
            input.index = pd.to_datetime(input.index, dayfirst=True)
            input = input.sort_index(ascending=False)

            # Calculate monthly percentage changes to enhance the stationarity of the data
            # Fill the first with 0
            index_df = input.iloc[:, 0].resample(rebal_period).first().pct_change().fillna(0)

             # Split the data into train and test based on the provided dates
            train_data = index_df.loc[start_date:test_start_dates]
            test_data = index_df.loc[test_start_dates:end_date]

            # Handle infinite values
            inf_indices_train = np.where(np.isinf(train_data))[0]
            inf_indices_test = np.where(np.isinf(test_data))[0]

            train_data[inf_indices_train] = np.nan
            test_data[inf_indices_test] = np.nan

            train_imputed, test_imputed = impute_data(train_data.values.reshape(-1, 1), test_data.values.reshape(-1, 1))

            # Convert back to Series
            train_imputed_series = pd.Series(train_imputed.flatten(), index=train_data.index)
            test_imputed_series = pd.Series(test_imputed.flatten(), index=test_data.index)

            # Rename the series for clarity
            train_imputed_series.rename(ind_name, inplace=True)
            test_imputed_series.rename(ind_name, inplace=True)

            result_train_df = pd.concat([result_train_df, train_imputed_series], axis=1)
            result_test_df = pd.concat([result_test_df, test_imputed_series], axis=1)
            
        except Exception as e:
            print(f"Error processing file: {index_data_name_file[ind_name]}")
            print(str(e))
            continue
    
    result_train_df.index = pd.to_datetime(result_train_df.index)
    result_test_df.index = pd.to_datetime(result_test_df.index)

    return result_train_df, result_test_df

# %%
# Define general parameters
train_start_date = '2007-01-01'
test_start_date = '2017-01-01'
test_end_date = '2022-12-31'
rebal_period = '1M'
train_data, test_data = load_feature_data(train_start_date, test_start_date, test_end_date, rebal_period)

# %%
train_data

# %%
test_data
# Out:
#             CBOE DJIA Volatility Index  CBOE NASDAQ Volatility Index  \
# 2017-01-31                   -0.039648                     -0.065192
# 2017-02-28                   -0.087920                     -0.184932
# 2017-03-31                    0.040235                     -0.014515
# 2017-04-30                   -0.066076                     -0.041085
# 2017-05-31                   -0.110440                     -0.013743
# 2017-06-30                   -0.039767                      0.040164
# 2017-07-31                    0.098990                      0.476753
# 2017-08-31                   -0.076287                     -0.208645
# 2017-09-30                    0.056716                     -0.049225
# 2017-10-31                   -0.038606                     -0.015603
# 2017-11-30                    0.060725                      0.077089
# 2017-12-31                    0.302862                      0.108361
# 2018-01-31                   -0.216867                     -0.098974
# 2018-02-28                    0.321267                      0.282652
# 2018-03-31                    0.428767                      0.291906
# 2018-04-30                    0.186002                      0.209378
# 2018-05-31                   -0.299515                     -0.341243
# 2018-06-30                   -0.170802                     -0.233384
# 2018-07-31                    0.128045                      0.377234
# 2018-08-31                   -0.106724                     -0.111485
# 2018-09-30                   -0.044890                     -0.075176
# 2018-10-31                   -0.028923                     -0.000585
# 2018-11-30                    0.482502                      0.528379
# 2018-12-31                    0.053240                     -0.028331
# 2019-01-31                    0.099666                      0.185579
# 2019-02-28                   -0.274501                     -0.341974
# 2019-03-31                   -0.161387                     -0.185859
# 2019-04-30                   -0.009266                      0.011787
# 2019-05-31                    0.053237                      0.099326
# 2019-06-30                    0.286202                      0.350809
# 2017-12-31                                          -0.705140
# 2018-01-31                                           0.020344
# 2018-02-28                                           0.046782
# 2018-03-31                                           2.670763
# 2018-04-30                                          -0.750810
# 2018-05-31                                           2.979243
# 2018-06-30                                           0.030060
# 2018-07-31                                          -0.003270
# 2018-08-31                                           0.032072
# 2018-09-30                                          -0.733885
# 2018-10-31                                           2.907443
# 2018-11-30                                          -0.757907
# 2018-12-31                                           2.939850
# 2019-01-31                                          -0.100202
# 2019-02-28                                           0.077360
# 2019-03-31                                          -0.732112
# 2019-04-30                                           2.956018
# 2019-05-31                                          -0.736398
# 2019-06-30                                           2.626846
# 2019-07-31                                           0.080667
# 2019-08-31                                          -0.742285
# 2019-09-30                                           2.802130
# 2019-10-31                                          -0.738161
# 2019-11-30                                           3.032206
# 2019-12-31                                           0.015356
# 2020-01-31                                          -0.531695
# 2020-02-29                                           1.228465
# 2020-03-31                                          -0.261781
# 2020-04-30                                          -0.076482
# 2020-05-31                                           0.149674
# 2020-06-30                                           0.077018
# 2020-07-31                                           0.134341
# 2020-08-31                                          -0.726115
# 2020-09-30                                           0.070461
# 2020-10-31                                           2.700588
# 2020-11-30                                          -0.746463
# 2020-12-31                                           3.280159
# 2021-01-31                                           0.010203
# 2021-02-28                                          -0.355968
# 2021-03-31                                          -0.576553
# 2021-04-30                                           3.354287
# 2021-05-31                                          -0.753199
# 2021-06-30                                           0.002254
# 2021-07-31                                           2.572314
# 2021-08-31                                           0.131579
# 2021-09-30                                          -0.733644
# 2021-10-31                                          -0.036995
# 2021-11-30                                           3.102330
# 2021-12-31                                           0.067651
# 2022-01-31                                          -0.026226
# 2022-02-28                                          -0.052502
# 2022-03-31                                          -0.053723
# 2022-04-30                                          -0.527686
# 2022-05-31                                          -0.086211
# 2022-06-30                                           1.210295
# 2022-07-31                                          -0.068844
# 2022-08-31                                           0.077795
# 2022-09-30                                          -0.751299
# 2022-10-31                                          -0.072913
# 2022-11-30                                           0.048247
# 2022-12-31                                           0.057421

# %%
# get target index data
def index_cum_data_loading(start_date, test_start_dates, end_date, rebal_period):
    index_data_dir = os.path.join(os.getcwd(), 'data', 'index_data')
    result_train_df = pd.DataFrame()
    result_test_df = pd.DataFrame()
    
    index_data_name_file = {
        'CRSP Daily Stock Market Indexes - Level of the S&P 500 Index':'CRSP Daily Stock Market Indexes - Level of the S&P 500 Index.xlsx'
    }
    
    for ind_name in index_data_name_file.keys():
        try:
            input = pd.read_excel(os.path.join(index_data_dir, index_data_name_file[ind_name]), index_col='Date')
            # Ensure that the index is a DatetimeIndex
            input.index = pd.to_datetime(input.index, dayfirst=True)
            input = input.sort_index(ascending=False)
            
            reb_index = input.iloc[:, 0].resample(rebal_period).first()
            index_df = reb_index / reb_index.iloc[0]
            
             # Split the data into train and test based on the provided dates
            train_data = index_df.loc[start_date:test_start_dates]
            test_data = index_df.loc[test_start_dates:end_date]
            
            # Split the data into train and test based on the provided dates
            train_data = index_df.loc[start_date:test_start_dates]
            test_data = index_df.loc[test_start_dates:end_date]

            train_imputed, test_imputed = impute_data(train_data.values.reshape(-1, 1), test_data.values.reshape(-1, 1))

            # Convert back to Series
            train_imputed_series = pd.Series(train_imputed.flatten(), index=train_data.index)
            test_imputed_series = pd.Series(test_imputed.flatten(), index=test_data.index)

            # Rename the series for clarity
            train_imputed_series.rename(ind_name, inplace=True)
            test_imputed_series.rename(ind_name, inplace=True)

            result_train_df = pd.concat([result_train_df, train_imputed_series], axis=1)
            result_test_df = pd.concat([result_test_df, test_imputed_series], axis=1)
            
        except Exception as e:
            print(f"Error processing file: {index_data_name_file[ind_name]}")
            print(str(e))
            continue

    result_train_df.index = pd.to_datetime(result_train_df.index)
    result_test_df.index = pd.to_datetime(result_test_df.index)

    return result_train_df, result_test_df

# %%
index_train_data, index_test_data = index_cum_data_loading(train_start_date, test_start_date, test_end_date, rebal_period)

# %%
index_train_data
# Out:
#             CRSP Daily Stock Market Indexes - Level of the S&P 500 Index
# 2007-01-31                                           1.000000
# 2007-02-28                                           1.020712
# 2007-03-31                                           0.990520
# 2007-04-30                                           1.005612
# 2007-05-31                                           1.049202
# 2007-06-30                                           1.084526
# 2007-07-31                                           1.072589
# 2007-08-31                                           1.034738
# 2007-09-30                                           1.051405
# 2007-10-31                                           1.092080
# 2007-11-30                                           1.064831
# 2007-12-31                                           1.039404
# 2008-01-31                                           1.021573
# 2008-02-29                                           0.985049
# 2008-03-31                                           0.939814
# 2008-04-30                                           0.967231
# 2008-05-31                                           0.994875
# 2008-06-30                                           0.978166
# 2008-07-31                                           0.907038
# 2008-08-31                                           0.889673
# 2008-09-30                                           0.901864
# 2008-10-31                                           0.819610
# 2008-11-30                                           0.682126
# 2008-12-31                                           0.576175
# 2009-01-31                                           0.657772
# 2009-02-28                                           0.582691
# 2009-03-31                                           0.494720
# 2009-04-30                                           0.572554
# 2009-05-31                                           0.619455
# 2009-06-30                                           0.665587
# 2009-07-31                                           0.651793
# 2009-08-31                                           0.707772
# 2009-09-30                                           0.704532
# 2009-10-31                                           0.726987
# 2009-11-30                                           0.736185
# 2009-12-31                                           0.782762
# 2010-01-31                                           0.799795
# 2010-02-28                                           0.768876
# 2010-03-31                                           0.787597
# 2010-04-30                                           0.831639
# 2010-05-31                                           0.848694
# 2010-06-30                                           0.755831
# 2010-07-31                                           0.725236
# 2010-08-31                                           0.794762
# 2010-09-30                                           0.762594
# 2010-10-31                                           0.809149
# 2010-11-30                                           0.836072
# 2010-12-31                                           0.851384
# 2011-01-31                                           0.897833
# 2011-02-28                                           0.923048
# 2011-03-31                                           0.922159
# 2011-04-30                                           0.940569
# 2011-05-31                                           0.960906
# 2011-06-30                                           0.927961
# 2011-07-31                                           0.945694
# 2011-08-31                                           0.908471
# 2011-09-30                                           0.850219
# 2011-10-31                                           0.775964
# 2011-11-30                                           0.860003
# 2011-12-31                                           0.878568
# 2012-01-31                                           0.901497
# 2012-02-29                                           0.934696
# 2012-03-31                                           0.969992
# 2012-04-30                                           1.001722
# 2012-05-31                                           0.992390
# 2012-06-30                                           0.902188
# 2020-03-31                                           2.181442
# 2020-04-30                                           1.743964
# 2020-05-31                                           1.998242
# 2020-06-30                                           2.157087
# 2020-07-31                                           2.199534
# 2020-08-31                                           2.325717
# 2020-09-30                                           2.489517
# 2020-10-31                                           2.386559
# 2020-11-30                                           2.336750
# 2020-12-31                                           2.585380
# 2021-01-31                                           2.612346
# 2021-02-28                                           2.664027
# 2021-03-31                                           2.754356
# 2021-04-30                                           2.837689
# 2021-05-31                                           2.959664
# 2021-06-30                                           2.966286
# 2021-07-31                                           3.049513
# 2021-08-31                                           3.096965
# 2021-09-30                                           3.193626
# 2021-10-31                                           3.075702
# 2021-11-30                                           3.256862
# 2021-12-31                                           3.185825
# 2022-01-31                                           3.385966
# 2022-02-28                                           3.209473
# 2022-03-31                                           3.039856
# 2022-04-30                                           3.208993
# 2022-05-31                                           2.933347
# 2022-06-30                                           2.895122
# 2022-07-31                                           2.700360
# 2022-08-31                                           2.907405
# 2022-09-30                                           2.800261
# 2022-10-31                                           2.596661
# 2022-11-30                                           2.722081
# 2022-12-31                                           2.877714

# %%
def plot_target_index(word_index):
    ax = word_index.plot()
    ax.get_yaxis().set_major_formatter(plt.FuncFormatter(lambda x, loc: "{:.2f}".format(float(x))))
    plt.xlabel('Date')
    plt.ylabel('Cumulative P&L')
    plt.title('Cumulative Profit and Loss')
    plt.show()

# %%
plot_target_index(index_train_data)

# %%
plot_target_index(index_test_data)

# %%
train_market_data = train_data.join(index_train_data, how = 'right')
test_market_data = test_data.join(index_test_data, how = 'right')

# %%
# Trying different method for feature selection
# Adjust display options to show the full correlation matrix
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
train_market_data.corr()
# Out:
#                                                     CBOE DJIA Volatility Index  \
# CBOE DJIA Volatility Index                                            1.000000
# CBOE NASDAQ Volatility Index                                          0.962420
# CBOE S&P100 Volatility Index                                          0.983334
# CBOE S&P500 Volatility Index                                          0.986630
# OptionMetrics - DJI Historical Volatility                             0.256359
# OptionMetrics - Russell 2000 Historical Volatility                    0.348441
# OptionMetrics - SPX Historical Volatility                             0.218198
# OptionMetrics - DJX  Index Dividend Yield                            -0.022280
# OptionMetrics - Russell 2000  Index Dividend Yield                   -0.129168
# OptionMetrics - SPX  Index Dividend Yield                            -0.126612
# OptionMetrics - Russel 2000 The total contract ...                    0.016530
# OptionMetrics - Russel 2000 Option Volume                             0.072345
# OptionMetrics - DJX Option Volume                                     0.082110
# OptionMetrics - DJX The total contract open int...                    0.112053
# OptionMetrics - SPX Option Volume                                     0.204092
# OptionMetrics - SPX The total contract open int...                   -0.038390
# OptionMetrics - DJX Calculated Price for the Un...                   -0.728651
# OptionMetrics - DJX Delta of the Option(CALL)                         0.199328
# OptionMetrics - DJX Implied Volatility of the O...                    0.822205
# OptionMetrics - DJX Interpolated Premium for th...                   -0.118027
# OptionMetrics - DJX Strike Price, Currently Alw...                   -0.215462
# OptionMetrics - DJX Theta of the Option(CALL)                         0.402364
# OptionMetrics - DJX VegaKappa of the Option(CALL)                    -0.237332
# OptionMetrics - Zero Coupon Yield Curve                              -0.020851
# OptionMetrics - DJX Calculated Price for the Un...                   -0.728651
# OptionMetrics - DJX Delta of the Option (PUT)                         0.034758
# OptionMetrics - DJX Gamma of the Option (PUT)                        -0.003795
# OptionMetrics - DJX Interpolated Premium for th...                   -0.113065
# OptionMetrics - DJX Strike Price, Currently Alw...                   -0.215462
# OptionMetrics - DJX Theta of the Option (PUT)                         0.245784
# OptionMetrics - DJX VegaKappa of the Option (PUT)                    -0.237393
# OptionMetrics - Russell 2000 Calculated Price f...                   -0.680427
# OptionMetrics - Russell 2000 Delta of the Optio...                    0.223346
# OptionMetrics - Russell 2000 Gamma of the Optio...                   -0.061578
# OptionMetrics - Russell 2000 Implied Volatility...                    0.778805
# OptionMetrics - Russell 2000 Interpolated Premi...                   -0.035525
# OptionMetrics - Russell 2000 Strike Price, Curr...                   -0.098036
# OptionMetrics - Russell 2000 Theta of the Optio...                    0.184718
# OptionMetrics - Russell 2000 VegaKappa of the O...                   -0.167811
# OptionMetrics - Russell 2000 VegaKappa of the O...                   -0.167846
# OptionMetrics - Russell 2000 Theta of the Optio...                    0.141303
# OptionMetrics - Russell 2000 Gamma of the Optio...                   -0.069409
# OptionMetrics - Russell 2000 Delta of the Optio...                   -0.124619
# OptionMetrics - Russell 2000 Implied Volatility...                    0.820778
# OptionMetrics - Russell 2000 Interpolated Premi...                   -0.030869
# OptionMetrics - Russell 2000 Strike Price, Curr...                   -0.098036
# OptionMetrics - Russell 2000 Calculated Price f...                   -0.680427
# OptionMetrics - SPX Calculated Price for the Un...                   -0.726875
# OptionMetrics - SPX Delta of the Option (CALL)                        0.274722
# OptionMetrics - SPX Gamma of the Option (CALL)                       -0.133090
# OptionMetrics - SPX Implied Volatility of the O...                    0.811610
# OptionMetrics - SPX Interpolated Premium for th...                    0.052462
# OptionMetrics - SPX Standardized Options (PUT)                       -0.726875
# OptionMetrics - SPX Strike Price, Currently Alw...                   -0.082172
# OptionMetrics - SPX Theta of the Option (CALL)                        0.365138
# OptionMetrics - SPX VegaKappa of the Option (PUT)                    -0.083562
# CRSP Daily Stock Market Indexes - Level of the ...                   -0.032132
#
#                                                     CBOE NASDAQ Volatility Index  \
# CBOE DJIA Volatility Index                                              0.962420
# CBOE NASDAQ Volatility Index                                            1.000000
# CBOE S&P100 Volatility Index                                            0.962173
# CBOE S&P500 Volatility Index                                            0.970423
# OptionMetrics - DJI Historical Volatility                               0.271833
# OptionMetrics - Russell 2000 Historical Volatility                      0.365280
# OptionMetrics - SPX Historical Volatility                               0.244795
# OptionMetrics - DJX  Index Dividend Yield                              -0.019093
# OptionMetrics - Russell 2000  Index Dividend Yield                     -0.152685
# OptionMetrics - SPX  Index Dividend Yield                              -0.113143
# OptionMetrics - Russel 2000 The total contract ...                      0.011622
# OptionMetrics - Russel 2000 Option Volume                               0.060511
# OptionMetrics - DJX Option Volume                                       0.090231
# OptionMetrics - DJX The total contract open int...                      0.111456
# OptionMetrics - SPX Option Volume                                       0.166402
# OptionMetrics - SPX The total contract open int...                     -0.068596
# OptionMetrics - DJX Calculated Price for the Un...                     -0.699238
# OptionMetrics - DJX Delta of the Option(CALL)                           0.179967
# OptionMetrics - DJX Implied Volatility of the O...                      0.805074
# OptionMetrics - DJX Interpolated Premium for th...                     -0.127375
# OptionMetrics - DJX Strike Price, Currently Alw...                     -0.229737
# OptionMetrics - DJX Theta of the Option(CALL)                           0.432091
# OptionMetrics - DJX VegaKappa of the Option(CALL)                      -0.246522
# OptionMetrics - Zero Coupon Yield Curve                                -0.022652
# OptionMetrics - DJX Calculated Price for the Un...                     -0.699238
# OptionMetrics - DJX Delta of the Option (PUT)                           0.033562
# OptionMetrics - DJX Gamma of the Option (PUT)                           0.017477
# OptionMetrics - DJX Interpolated Premium for th...                     -0.122707
# OptionMetrics - DJX Strike Price, Currently Alw...                     -0.229737
# OptionMetrics - DJX Theta of the Option (PUT)                           0.239660
# OptionMetrics - DJX VegaKappa of the Option (PUT)                      -0.246588
# OptionMetrics - Russell 2000 Calculated Price f...                     -0.690459
# OptionMetrics - Russell 2000 Delta of the Optio...                      0.242236
# OptionMetrics - Russell 2000 Gamma of the Optio...                     -0.097729
# OptionMetrics - Russell 2000 Implied Volatility...                      0.773750
# OptionMetrics - Russell 2000 Interpolated Premi...                     -0.016787
# OptionMetrics - Russell 2000 Strike Price, Curr...                     -0.124667
# OptionMetrics - Russell 2000 Theta of the Optio...                      0.141447
# OptionMetrics - Russell 2000 VegaKappa of the O...                     -0.145719
# OptionMetrics - Russell 2000 VegaKappa of the O...                     -0.145763
# OptionMetrics - Russell 2000 Theta of the Optio...                      0.097849
# OptionMetrics - Russell 2000 Gamma of the Optio...                     -0.104435
# OptionMetrics - Russell 2000 Delta of the Optio...                     -0.143059
# OptionMetrics - Russell 2000 Implied Volatility...                      0.811103
# OptionMetrics - Russell 2000 Interpolated Premi...                     -0.013860
# OptionMetrics - Russell 2000 Strike Price, Curr...                     -0.124667
# OptionMetrics - Russell 2000 Calculated Price f...                     -0.690459
# OptionMetrics - SPX Calculated Price for the Un...                     -0.719174
# OptionMetrics - SPX Delta of the Option (CALL)                          0.237447
# OptionMetrics - SPX Gamma of the Option (CALL)                         -0.114915
# OptionMetrics - SPX Implied Volatility of the O...                      0.818808
# OptionMetrics - SPX Interpolated Premium for th...                      0.032574
# OptionMetrics - SPX Standardized Options (PUT)                         -0.719174
# OptionMetrics - SPX Strike Price, Currently Alw...                     -0.097950
# OptionMetrics - SPX Theta of the Option (CALL)                          0.401702
# OptionMetrics - SPX VegaKappa of the Option (PUT)                      -0.117744
# CRSP Daily Stock Market Indexes - Level of the ...                     -0.015777
#
#                                                     CBOE S&P100 Volatility Index  \
# CBOE DJIA Volatility Index                                              0.983334
# CBOE NASDAQ Volatility Index                                            0.962173
# CBOE S&P100 Volatility Index                                            1.000000
# CBOE S&P500 Volatility Index                                            0.985493
# OptionMetrics - DJI Historical Volatility                               0.254711
# OptionMetrics - Russell 2000 Historical Volatility                      0.344136
# OptionMetrics - SPX Historical Volatility                               0.215381
# OptionMetrics - DJX  Index Dividend Yield                              -0.004059
# OptionMetrics - Russell 2000  Index Dividend Yield                     -0.097354
# OptionMetrics - SPX  Index Dividend Yield                              -0.107822
# OptionMetrics - Russel 2000 The total contract ...                      0.015561
# OptionMetrics - Russel 2000 Option Volume                               0.073819
# OptionMetrics - DJX Option Volume                                       0.086951
# OptionMetrics - DJX The total contract open int...                      0.130560
# OptionMetrics - SPX Option Volume                                       0.216244
# OptionMetrics - SPX The total contract open int...                     -0.039977
# OptionMetrics - DJX Calculated Price for the Un...                     -0.704416
# OptionMetrics - DJX Delta of the Option(CALL)                           0.186745
# OptionMetrics - DJX Implied Volatility of the O...                      0.804707
# OptionMetrics - DJX Interpolated Premium for th...                     -0.141570
# OptionMetrics - DJX Strike Price, Currently Alw...                     -0.228219
# OptionMetrics - DJX Theta of the Option(CALL)                           0.403165
# OptionMetrics - DJX VegaKappa of the Option(CALL)                      -0.244145
# OptionMetrics - Zero Coupon Yield Curve                                -0.027726
# OptionMetrics - DJX Calculated Price for the Un...                     -0.704416
# OptionMetrics - DJX Delta of the Option (PUT)                           0.043806
# OptionMetrics - DJX Gamma of the Option (PUT)                          -0.003945
# OptionMetrics - DJX Interpolated Premium for th...                     -0.137412
# OptionMetrics - DJX Strike Price, Currently Alw...                     -0.228219
# OptionMetrics - DJX Theta of the Option (PUT)                           0.246141
# OptionMetrics - DJX VegaKappa of the Option (PUT)                      -0.244189
# OptionMetrics - Russell 2000 Calculated Price f...                     -0.665403
# OptionMetrics - Russell 2000 Delta of the Optio...                      0.200773
# OptionMetrics - Russell 2000 Gamma of the Optio...                     -0.056606
# OptionMetrics - Russell 2000 Implied Volatility...                      0.753706
# OptionMetrics - Russell 2000 Interpolated Premi...                     -0.062303
# OptionMetrics - Russell 2000 Strike Price, Curr...                     -0.080635
# OptionMetrics - Russell 2000 Theta of the Optio...                      0.181862
# OptionMetrics - Russell 2000 VegaKappa of the O...                     -0.193228
# OptionMetrics - Russell 2000 VegaKappa of the O...                     -0.193263
# OptionMetrics - Russell 2000 Theta of the Optio...                      0.138083
# OptionMetrics - Russell 2000 Gamma of the Optio...                     -0.063983
# OptionMetrics - Russell 2000 Delta of the Optio...                     -0.111869
# OptionMetrics - Russell 2000 Implied Volatility...                      0.796855
# OptionMetrics - Russell 2000 Interpolated Premi...                     -0.057488
# OptionMetrics - Russell 2000 Strike Price, Curr...                     -0.080635
# OptionMetrics - Russell 2000 Calculated Price f...                     -0.665403
# OptionMetrics - SPX Calculated Price for the Un...                     -0.704400
# OptionMetrics - SPX Delta of the Option (CALL)                          0.235334
# OptionMetrics - SPX Gamma of the Option (CALL)                         -0.108920
# OptionMetrics - SPX Implied Volatility of the O...                      0.804493
# OptionMetrics - SPX Interpolated Premium for th...                      0.039280
# OptionMetrics - SPX Standardized Options (PUT)                         -0.704400
# OptionMetrics - SPX Strike Price, Currently Alw...                     -0.077437
# OptionMetrics - SPX Theta of the Option (CALL)                          0.398137
# OptionMetrics - SPX VegaKappa of the Option (PUT)                      -0.103215
# CRSP Daily Stock Market Indexes - Level of the ...                     -0.018350
#
#                                                     CBOE S&P500 Volatility Index  \
# CBOE DJIA Volatility Index                                              0.986630
# CBOE NASDAQ Volatility Index                                            0.970423
# CBOE S&P100 Volatility Index                                            0.985493
# CBOE S&P500 Volatility Index                                            1.000000
# OptionMetrics - DJI Historical Volatility                               0.273064
# OptionMetrics - Russell 2000 Historical Volatility                      0.362908
# OptionMetrics - SPX Historical Volatility                               0.236328
# OptionMetrics - DJX  Index Dividend Yield                              -0.020392
# OptionMetrics - Russell 2000  Index Dividend Yield                     -0.125745
# OptionMetrics - SPX  Index Dividend Yield                              -0.114496
# OptionMetrics - Russel 2000 The total contract ...                     -0.004138
# OptionMetrics - Russel 2000 Option Volume                               0.063200
# OptionMetrics - DJX Option Volume                                       0.068510
# OptionMetrics - DJX The total contract open int...                      0.117134
# OptionMetrics - SPX Option Volume                                       0.190295
# OptionMetrics - SPX The total contract open int...                     -0.053094
# OptionMetrics - DJX Calculated Price for the Un...                     -0.697496
# OptionMetrics - DJX Delta of the Option(CALL)                           0.183245
# OptionMetrics - DJX Implied Volatility of the O...                      0.818868
# OptionMetrics - DJX Interpolated Premium for th...                     -0.127439
# OptionMetrics - DJX Strike Price, Currently Alw...                     -0.226753
# OptionMetrics - DJX Theta of the Option(CALL)                           0.426341
# OptionMetrics - DJX VegaKappa of the Option(CALL)                      -0.236810
# OptionMetrics - Zero Coupon Yield Curve                                -0.005815
# OptionMetrics - DJX Calculated Price for the Un...                     -0.697496
# OptionMetrics - DJX Delta of the Option (PUT)                           0.044585
# OptionMetrics - DJX Gamma of the Option (PUT)                           0.005756
# OptionMetrics - DJX Interpolated Premium for th...                     -0.125037
# OptionMetrics - DJX Strike Price, Currently Alw...                     -0.226753
# OptionMetrics - DJX Theta of the Option (PUT)                           0.253058
# OptionMetrics - DJX VegaKappa of the Option (PUT)                      -0.236855
# OptionMetrics - Russell 2000 Calculated Price f...                     -0.654165
# OptionMetrics - Russell 2000 Delta of the Optio...                      0.216124
# OptionMetrics - Russell 2000 Gamma of the Optio...                     -0.074518
# OptionMetrics - Russell 2000 Implied Volatility...                      0.762360
# OptionMetrics - Russell 2000 Interpolated Premi...                     -0.040529
# OptionMetrics - Russell 2000 Strike Price, Curr...                     -0.096782
# OptionMetrics - Russell 2000 Theta of the Optio...                      0.163738
# OptionMetrics - Russell 2000 VegaKappa of the O...                     -0.171946
# OptionMetrics - Russell 2000 VegaKappa of the O...                     -0.171986
# OptionMetrics - Russell 2000 Theta of the Optio...                      0.124291
# OptionMetrics - Russell 2000 Gamma of the Optio...                     -0.082001
# OptionMetrics - Russell 2000 Delta of the Optio...                     -0.122904
# OptionMetrics - Russell 2000 Implied Volatility...                      0.806113
# OptionMetrics - Russell 2000 Interpolated Premi...                     -0.035446
# OptionMetrics - Russell 2000 Strike Price, Curr...                     -0.096782
# OptionMetrics - Russell 2000 Calculated Price f...                     -0.654165
# OptionMetrics - SPX Calculated Price for the Un...                     -0.701727
# OptionMetrics - SPX Delta of the Option (CALL)                          0.255326
# OptionMetrics - SPX Gamma of the Option (CALL)                         -0.122662
# OptionMetrics - SPX Implied Volatility of the O...                      0.822291
# OptionMetrics - SPX Interpolated Premium for th...                      0.050552
# OptionMetrics - SPX Standardized Options (PUT)                         -0.701727
# OptionMetrics - SPX Strike Price, Currently Alw...                     -0.071108
# OptionMetrics - SPX Theta of the Option (CALL)                          0.406364
# OptionMetrics - SPX VegaKappa of the Option (PUT)                      -0.089026
# CRSP Daily Stock Market Indexes - Level of the ...                     -0.023454
#
#                                                     OptionMetrics - DJI Historical Volatility  \
# CBOE DJIA Volatility Index                                                           0.256359
# CBOE NASDAQ Volatility Index                                                         0.271833
# CBOE S&P100 Volatility Index                                                         0.254711
# CBOE S&P500 Volatility Index                                                         0.273064
# OptionMetrics - DJI Historical Volatility                                            1.000000
# OptionMetrics - Russell 2000 Historical Volatility                                   0.797898
# OptionMetrics - SPX Historical Volatility                                            0.979492
# OptionMetrics - DJX  Index Dividend Yield                                            0.012044
# OptionMetrics - Russell 2000  Index Dividend Yield                                  -0.101799
# OptionMetrics - SPX  Index Dividend Yield                                           -0.048654
# OptionMetrics - Russel 2000 The total contract ...                                  -0.055875
# OptionMetrics - Russel 2000 Option Volume                                            0.146283
# OptionMetrics - DJX Option Volume                                                    0.113010
# OptionMetrics - DJX The total contract open int...                                  -0.060771
# OptionMetrics - SPX Option Volume                                                    0.117697
# OptionMetrics - SPX The total contract open int...                                  -0.085225
# OptionMetrics - DJX Calculated Price for the Un...                                  -0.197362
# OptionMetrics - DJX Delta of the Option(CALL)                                        0.098918
# OptionMetrics - DJX Implied Volatility of the O...                                   0.253041
# OptionMetrics - DJX Interpolated Premium for th...                                  -0.081511
# OptionMetrics - DJX Strike Price, Currently Alw...                                  -0.049335
# OptionMetrics - DJX Theta of the Option(CALL)                                        0.140616
# OptionMetrics - DJX VegaKappa of the Option(CALL)                                   -0.111206
# OptionMetrics - Zero Coupon Yield Curve                                              0.035796
# OptionMetrics - DJX Calculated Price for the Un...                                  -0.197362
# OptionMetrics - DJX Delta of the Option (PUT)                                       -0.039994
# OptionMetrics - DJX Gamma of the Option (PUT)                                        0.029667
# OptionMetrics - DJX Interpolated Premium for th...                                  -0.093446
# OptionMetrics - DJX Strike Price, Currently Alw...                                  -0.049335
# OptionMetrics - DJX Theta of the Option (PUT)                                        0.036726
# OptionMetrics - DJX VegaKappa of the Option (PUT)                                   -0.111128
# OptionMetrics - Russell 2000 Calculated Price f...                                  -0.135725
# OptionMetrics - Russell 2000 Delta of the Optio...                                   0.087228
# OptionMetrics - Russell 2000 Gamma of the Optio...                                  -0.080897
# OptionMetrics - Russell 2000 Implied Volatility...                                   0.224287
# OptionMetrics - Russell 2000 Interpolated Premi...                                  -0.003743
# OptionMetrics - Russell 2000 Strike Price, Curr...                                   0.046613
# OptionMetrics - Russell 2000 Theta of the Optio...                                  -0.010418
# OptionMetrics - Russell 2000 VegaKappa of the O...                                  -0.055625
# OptionMetrics - Russell 2000 VegaKappa of the O...                                  -0.055628
# OptionMetrics - Russell 2000 Theta of the Optio...                                  -0.029658
# OptionMetrics - Russell 2000 Gamma of the Optio...                                  -0.078796
# OptionMetrics - Russell 2000 Delta of the Optio...                                  -0.070153
# OptionMetrics - Russell 2000 Implied Volatility...                                   0.193925
# OptionMetrics - Russell 2000 Interpolated Premi...                                  -0.008398
# OptionMetrics - Russell 2000 Strike Price, Curr...                                   0.046613
# OptionMetrics - Russell 2000 Calculated Price f...                                  -0.135725
# OptionMetrics - SPX Calculated Price for the Un...                                  -0.189040
# OptionMetrics - SPX Delta of the Option (CALL)                                      -0.011722
# OptionMetrics - SPX Gamma of the Option (CALL)                                      -0.043795
# OptionMetrics - SPX Implied Volatility of the O...                                   0.288559
# OptionMetrics - SPX Interpolated Premium for th...                                  -0.045934
# OptionMetrics - SPX Standardized Options (PUT)                                      -0.189040
# OptionMetrics - SPX Strike Price, Currently Alw...                                   0.000162
# OptionMetrics - SPX Theta of the Option (CALL)                                       0.206965
# OptionMetrics - SPX VegaKappa of the Option (PUT)                                   -0.094360
# CRSP Daily Stock Market Indexes - Level of the ...                                  -0.031404
#
#                                                     OptionMetrics - Russell 2000 Historical Volatility  \
# CBOE DJIA Volatility Index                                                                   0.348441
# CBOE NASDAQ Volatility Index                                                                 0.365280
# CBOE S&P100 Volatility Index                                                                 0.344136
# CBOE S&P500 Volatility Index                                                                 0.362908
# OptionMetrics - DJI Historical Volatility                                                    0.797898
# OptionMetrics - Russell 2000 Historical Volatility                                           1.000000
# OptionMetrics - SPX Historical Volatility                                                    0.782725
# OptionMetrics - DJX  Index Dividend Yield                                                    0.038662
# OptionMetrics - Russell 2000  Index Dividend Yield                                          -0.117990
# OptionMetrics - SPX  Index Dividend Yield                                                   -0.064902
# OptionMetrics - Russel 2000 The total contract ...                                           0.051806
# OptionMetrics - Russel 2000 Option Volume                                                    0.107148
# OptionMetrics - DJX Option Volume                                                            0.094417
# OptionMetrics - DJX The total contract open int...                                           0.002841
# OptionMetrics - SPX Option Volume                                                            0.128808
# OptionMetrics - SPX The total contract open int...                                           0.006473
# OptionMetrics - DJX Calculated Price for the Un...                                          -0.265494
# OptionMetrics - DJX Delta of the Option(CALL)                                                0.090430
# OptionMetrics - DJX Implied Volatility of the O...                                           0.298869
# OptionMetrics - DJX Interpolated Premium for th...                                          -0.078958
# OptionMetrics - DJX Strike Price, Currently Alw...                                          -0.113199
# OptionMetrics - DJX Theta of the Option(CALL)                                                0.192450
# OptionMetrics - DJX VegaKappa of the Option(CALL)                                           -0.150223
# OptionMetrics - Zero Coupon Yield Curve                                                      0.080297
# OptionMetrics - DJX Calculated Price for the Un...                                          -0.265494
# OptionMetrics - DJX Delta of the Option (PUT)                                               -0.026795
# OptionMetrics - DJX Gamma of the Option (PUT)                                                0.089810
# OptionMetrics - DJX Interpolated Premium for th...                                          -0.105204
# OptionMetrics - DJX Strike Price, Currently Alw...                                          -0.113199
# OptionMetrics - DJX Theta of the Option (PUT)                                                0.061423
# OptionMetrics - DJX VegaKappa of the Option (PUT)                                           -0.150159
# OptionMetrics - Russell 2000 Calculated Price f...                                          -0.226363
# OptionMetrics - Russell 2000 Delta of the Optio...                                           0.074338
# OptionMetrics - Russell 2000 Gamma of the Optio...                                          -0.095510
# OptionMetrics - Russell 2000 Implied Volatility...                                           0.337665
# OptionMetrics - Russell 2000 Interpolated Premi...                                          -0.008675
# OptionMetrics - Russell 2000 Strike Price, Curr...                                          -0.071517
# OptionMetrics - Russell 2000 Theta of the Optio...                                           0.029102
# OptionMetrics - Russell 2000 VegaKappa of the O...                                          -0.079137
# OptionMetrics - Russell 2000 VegaKappa of the O...                                          -0.079149
# OptionMetrics - Russell 2000 Theta of the Optio...                                           0.003453
# OptionMetrics - Russell 2000 Gamma of the Optio...                                          -0.089155
# OptionMetrics - Russell 2000 Delta of the Optio...                                          -0.050974
# OptionMetrics - Russell 2000 Implied Volatility...                                           0.287562
# OptionMetrics - Russell 2000 Interpolated Premi...                                          -0.023001
# OptionMetrics - Russell 2000 Strike Price, Curr...                                          -0.071517
# OptionMetrics - Russell 2000 Calculated Price f...                                          -0.226363
# OptionMetrics - SPX Calculated Price for the Un...                                          -0.265771
# OptionMetrics - SPX Delta of the Option (CALL)                                               0.044672
# OptionMetrics - SPX Gamma of the Option (CALL)                                              -0.070478
# OptionMetrics - SPX Implied Volatility of the O...                                           0.369531
# OptionMetrics - SPX Interpolated Premium for th...                                          -0.033192
# OptionMetrics - SPX Standardized Options (PUT)                                              -0.265771
# OptionMetrics - SPX Strike Price, Currently Alw...                                          -0.005298
# OptionMetrics - SPX Theta of the Option (CALL)                                               0.230113
# OptionMetrics - SPX VegaKappa of the Option (PUT)                                           -0.094752
# CRSP Daily Stock Market Indexes - Level of the ...                                          -0.004509
#
#                                                     OptionMetrics - SPX Historical Volatility  \
# CBOE DJIA Volatility Index                                                           0.218198
# CBOE NASDAQ Volatility Index                                                         0.244795
# CBOE S&P100 Volatility Index                                                         0.215381
# CBOE S&P500 Volatility Index                                                         0.236328
# OptionMetrics - DJI Historical Volatility                                            0.979492
# OptionMetrics - Russell 2000 Historical Volatility                                   0.782725
# OptionMetrics - SPX Historical Volatility                                            1.000000
# OptionMetrics - DJX  Index Dividend Yield                                            0.005523
# OptionMetrics - Russell 2000  Index Dividend Yield                                  -0.090642
# OptionMetrics - SPX  Index Dividend Yield                                           -0.038282
# OptionMetrics - Russel 2000 The total contract ...                                  -0.044242
# OptionMetrics - Russel 2000 Option Volume                                            0.138777
# OptionMetrics - DJX Option Volume                                                    0.084982
# OptionMetrics - DJX The total contract open int...                                  -0.078275
# OptionMetrics - SPX Option Volume                                                    0.101558
# OptionMetrics - SPX The total contract open int...                                  -0.078922
# OptionMetrics - DJX Calculated Price for the Un...                                  -0.147136
# OptionMetrics - DJX Delta of the Option(CALL)                                        0.067798
# OptionMetrics - DJX Implied Volatility of the O...                                   0.213024
# OptionMetrics - DJX Interpolated Premium for th...                                  -0.070858
# OptionMetrics - DJX Strike Price, Currently Alw...                                  -0.044776
# OptionMetrics - DJX Theta of the Option(CALL)                                        0.127992
# OptionMetrics - DJX VegaKappa of the Option(CALL)                                   -0.092451
# OptionMetrics - Zero Coupon Yield Curve                                              0.064300
# OptionMetrics - DJX Calculated Price for the Un...                                  -0.147136
# OptionMetrics - DJX Delta of the Option (PUT)                                       -0.020864
# OptionMetrics - DJX Gamma of the Option (PUT)                                        0.034602
# OptionMetrics - DJX Interpolated Premium for th...                                  -0.083235
# OptionMetrics - DJX Strike Price, Currently Alw...                                  -0.044776
# OptionMetrics - DJX Theta of the Option (PUT)                                        0.028244
# OptionMetrics - DJX VegaKappa of the Option (PUT)                                   -0.092379
# OptionMetrics - Russell 2000 Calculated Price f...                                  -0.083908
# OptionMetrics - Russell 2000 Delta of the Optio...                                   0.049399
# OptionMetrics - Russell 2000 Gamma of the Optio...                                  -0.074103
# OptionMetrics - Russell 2000 Implied Volatility...                                   0.182448
# OptionMetrics - Russell 2000 Interpolated Premi...                                  -0.017846
# OptionMetrics - Russell 2000 Strike Price, Curr...                                   0.021187
# OptionMetrics - Russell 2000 Theta of the Optio...                                  -0.006729
# OptionMetrics - Russell 2000 VegaKappa of the O...                                  -0.067408
# OptionMetrics - Russell 2000 VegaKappa of the O...                                  -0.067410
# OptionMetrics - Russell 2000 Theta of the Optio...                                  -0.026038
# OptionMetrics - Russell 2000 Gamma of the Optio...                                  -0.070576
# OptionMetrics - Russell 2000 Delta of the Optio...                                  -0.039453
# OptionMetrics - Russell 2000 Implied Volatility...                                   0.152952
# OptionMetrics - Russell 2000 Interpolated Premi...                                  -0.022640
# OptionMetrics - Russell 2000 Strike Price, Curr...                                   0.021187
# OptionMetrics - Russell 2000 Calculated Price f...                                  -0.083908
# OptionMetrics - SPX Calculated Price for the Un...                                  -0.145484
# OptionMetrics - SPX Delta of the Option (CALL)                                       0.003204
# OptionMetrics - SPX Gamma of the Option (CALL)                                      -0.049572
# OptionMetrics - SPX Implied Volatility of the O...                                   0.257659
# OptionMetrics - SPX Interpolated Premium for th...                                  -0.020640
# OptionMetrics - SPX Standardized Options (PUT)                                      -0.145484
# OptionMetrics - SPX Strike Price, Currently Alw...                                   0.011588
# OptionMetrics - SPX Theta of the Option (CALL)                                       0.171183
# OptionMetrics - SPX VegaKappa of the Option (PUT)                                   -0.067324
# CRSP Daily Stock Market Indexes - Level of the ...                                  -0.021322
#
#                                                     OptionMetrics - DJX  Index Dividend Yield  \
# CBOE DJIA Volatility Index                                                          -0.022280
# CBOE NASDAQ Volatility Index                                                        -0.019093
# CBOE S&P100 Volatility Index                                                        -0.004059
# CBOE S&P500 Volatility Index                                                        -0.020392
# OptionMetrics - DJI Historical Volatility                                            0.012044
# OptionMetrics - Russell 2000 Historical Volatility                                   0.038662
# OptionMetrics - SPX Historical Volatility                                            0.005523
# OptionMetrics - DJX  Index Dividend Yield                                            1.000000
# OptionMetrics - Russell 2000  Index Dividend Yield                                   0.625637
# OptionMetrics - SPX  Index Dividend Yield                                            0.851138
# OptionMetrics - Russel 2000 The total contract ...                                  -0.165838
# OptionMetrics - Russel 2000 Option Volume                                            0.040359
# OptionMetrics - DJX Option Volume                                                    0.065536
# OptionMetrics - DJX The total contract open int...                                  -0.189753
# OptionMetrics - SPX Option Volume                                                   -0.043816
# OptionMetrics - SPX The total contract open int...                                  -0.180751
# OptionMetrics - DJX Calculated Price for the Un...                                   0.088951
# OptionMetrics - DJX Delta of the Option(CALL)                                        0.097185
# OptionMetrics - DJX Implied Volatility of the O...                                  -0.010793
# OptionMetrics - DJX Interpolated Premium for th...                                   0.013394
# OptionMetrics - DJX Strike Price, Currently Alw...                                  -0.078902
# OptionMetrics - DJX Theta of the Option(CALL)                                       -0.128775
# OptionMetrics - DJX VegaKappa of the Option(CALL)                                    0.162860
# OptionMetrics - Zero Coupon Yield Curve                                             -0.026772
# OptionMetrics - DJX Calculated Price for the Un...                                   0.088951
# OptionMetrics - DJX Delta of the Option (PUT)                                       -0.151977
# OptionMetrics - DJX Gamma of the Option (PUT)                                       -0.110713
# OptionMetrics - DJX Interpolated Premium for th...                                   0.001649
# OptionMetrics - DJX Strike Price, Currently Alw...                                  -0.078902
# OptionMetrics - DJX Theta of the Option (PUT)                                       -0.068169
# OptionMetrics - DJX VegaKappa of the Option (PUT)                                    0.163000
# OptionMetrics - Russell 2000 Calculated Price f...                                   0.101527
# OptionMetrics - Russell 2000 Delta of the Optio...                                  -0.067741
# OptionMetrics - Russell 2000 Gamma of the Optio...                                   0.002101
# OptionMetrics - Russell 2000 Implied Volatility...                                  -0.013803
# OptionMetrics - Russell 2000 Interpolated Premi...                                   0.011365
# OptionMetrics - Russell 2000 Strike Price, Curr...                                   0.095117
# OptionMetrics - Russell 2000 Theta of the Optio...                                   0.005921
# OptionMetrics - Russell 2000 VegaKappa of the O...                                  -0.025016
# OptionMetrics - Russell 2000 VegaKappa of the O...                                  -0.024938
# OptionMetrics - Russell 2000 Theta of the Optio...                                   0.017716
# OptionMetrics - Russell 2000 Gamma of the Optio...                                   0.011783
# OptionMetrics - Russell 2000 Delta of the Optio...                                   0.032169
# OptionMetrics - Russell 2000 Implied Volatility...                                  -0.062007
# OptionMetrics - Russell 2000 Interpolated Premi...                                   0.005364
# OptionMetrics - Russell 2000 Strike Price, Curr...                                   0.095117
# OptionMetrics - Russell 2000 Calculated Price f...                                   0.101527
# OptionMetrics - SPX Calculated Price for the Un...                                   0.146839
# OptionMetrics - SPX Delta of the Option (CALL)                                      -0.055693
# OptionMetrics - SPX Gamma of the Option (CALL)                                       0.018627
# OptionMetrics - SPX Implied Volatility of the O...                                  -0.036395
# OptionMetrics - SPX Interpolated Premium for th...                                  -0.055959
# OptionMetrics - SPX Standardized Options (PUT)                                       0.146839
# OptionMetrics - SPX Strike Price, Currently Alw...                                   0.000969
# OptionMetrics - SPX Theta of the Option (CALL)                                       0.030844
# OptionMetrics - SPX VegaKappa of the Option (PUT)                                   -0.007301
# CRSP Daily Stock Market Indexes - Level of the ...                                  -0.017889
#
#                                                     OptionMetrics - Russell 2000  Index Dividend Yield  \
# CBOE DJIA Volatility Index                                                                  -0.129168
# CBOE NASDAQ Volatility Index                                                                -0.152685
# CBOE S&P100 Volatility Index                                                                -0.097354
# CBOE S&P500 Volatility Index                                                                -0.125745
# OptionMetrics - DJI Historical Volatility                                                   -0.101799
# OptionMetrics - Russell 2000 Historical Volatility                                          -0.117990
# OptionMetrics - SPX Historical Volatility                                                   -0.090642
# OptionMetrics - DJX  Index Dividend Yield                                                    0.625637
# OptionMetrics - Russell 2000  Index Dividend Yield                                           1.000000
# OptionMetrics - SPX  Index Dividend Yield                                                    0.739041
# OptionMetrics - Russel 2000 The total contract ...                                          -0.111243
# OptionMetrics - Russel 2000 Option Volume                                                   -0.029823
# OptionMetrics - DJX Option Volume                                                           -0.010262
# OptionMetrics - DJX The total contract open int...                                          -0.169207
# OptionMetrics - SPX Option Volume                                                           -0.077948
# OptionMetrics - SPX The total contract open int...                                          -0.131800
# OptionMetrics - DJX Calculated Price for the Un...                                           0.131018
# OptionMetrics - DJX Delta of the Option(CALL)                                               -0.059785
# OptionMetrics - DJX Implied Volatility of the O...                                          -0.150545
# OptionMetrics - DJX Interpolated Premium for th...                                          -0.027651
# OptionMetrics - DJX Strike Price, Currently Alw...                                          -0.030028
# OptionMetrics - DJX Theta of the Option(CALL)                                               -0.031230
# OptionMetrics - DJX VegaKappa of the Option(CALL)                                            0.114451
# OptionMetrics - Zero Coupon Yield Curve                                                     -0.010654
# OptionMetrics - DJX Calculated Price for the Un...                                           0.131018
# OptionMetrics - DJX Delta of the Option (PUT)                                               -0.057776
# OptionMetrics - DJX Gamma of the Option (PUT)                                                0.004239
# OptionMetrics - DJX Interpolated Premium for th...                                          -0.037686
# OptionMetrics - DJX Strike Price, Currently Alw...                                          -0.030028
# OptionMetrics - DJX Theta of the Option (PUT)                                               -0.022751
# OptionMetrics - DJX VegaKappa of the Option (PUT)                                            0.114641
# OptionMetrics - Russell 2000 Calculated Price f...                                           0.211455
# OptionMetrics - Russell 2000 Delta of the Optio...                                          -0.080867
# OptionMetrics - Russell 2000 Gamma of the Optio...                                          -0.001706
# OptionMetrics - Russell 2000 Implied Volatility...                                          -0.170147
# OptionMetrics - Russell 2000 Interpolated Premi...                                          -0.014553
# OptionMetrics - Russell 2000 Strike Price, Curr...                                           0.062099
# OptionMetrics - Russell 2000 Theta of the Optio...                                          -0.042613
# OptionMetrics - Russell 2000 VegaKappa of the O...                                           0.021114
# OptionMetrics - Russell 2000 VegaKappa of the O...                                           0.021236
# OptionMetrics - Russell 2000 Theta of the Optio...                                          -0.047486
# OptionMetrics - Russell 2000 Gamma of the Optio...                                           0.005792
# OptionMetrics - Russell 2000 Delta of the Optio...                                           0.009021
# OptionMetrics - Russell 2000 Implied Volatility...                                          -0.217770
# OptionMetrics - Russell 2000 Interpolated Premi...                                          -0.019645
# OptionMetrics - Russell 2000 Strike Price, Curr...                                           0.062099
# OptionMetrics - Russell 2000 Calculated Price f...                                           0.211455
# OptionMetrics - SPX Calculated Price for the Un...                                           0.213305
# OptionMetrics - SPX Delta of the Option (CALL)                                              -0.109530
# OptionMetrics - SPX Gamma of the Option (CALL)                                              -0.024865
# OptionMetrics - SPX Implied Volatility of the O...                                          -0.131889
# ...
# OptionMetrics - DJX Gamma of the Option (PUT)                                             0.122784
# OptionMetrics - DJX Interpolated Premium for th...                                       -0.216534
# OptionMetrics - DJX Strike Price, Currently Alw...                                       -0.254135
# OptionMetrics - DJX Theta of the Option (PUT)                                             0.195389
# OptionMetrics - DJX VegaKappa of the Option (PUT)                                        -0.219267
# OptionMetrics - Russell 2000 Calculated Price f...                                       -0.218123
# OptionMetrics - Russell 2000 Delta of the Optio...                                       -0.009079
# OptionMetrics - Russell 2000 Gamma of the Optio...                                        0.085005
# OptionMetrics - Russell 2000 Implied Volatility...                                        0.191925
# OptionMetrics - Russell 2000 Interpolated Premi...                                       -0.056050
# OptionMetrics - Russell 2000 Strike Price, Curr...                                       -0.063690
# OptionMetrics - Russell 2000 Theta of the Optio...                                        0.152169
# OptionMetrics - Russell 2000 VegaKappa of the O...                                       -0.127613
# OptionMetrics - Russell 2000 VegaKappa of the O...                                       -0.127614
# OptionMetrics - Russell 2000 Theta of the Optio...                                        0.133454
# OptionMetrics - Russell 2000 Gamma of the Optio...                                        0.079898
# OptionMetrics - Russell 2000 Delta of the Optio...                                        0.040142
# OptionMetrics - Russell 2000 Implied Volatility...                                        0.210466
# OptionMetrics - Russell 2000 Interpolated Premi...                                       -0.061671
# OptionMetrics - Russell 2000 Strike Price, Curr...                                       -0.063690
# OptionMetrics - Russell 2000 Calculated Price f...                                       -0.218123
# OptionMetrics - SPX Calculated Price for the Un...                                       -0.164094
# OptionMetrics - SPX Delta of the Option (CALL)                                           -0.587624
# OptionMetrics - SPX Gamma of the Option (CALL)                                            0.700240
# OptionMetrics - SPX Implied Volatility of the O...                                        0.120294
# OptionMetrics - SPX Interpolated Premium for th...                                       -0.490832
# OptionMetrics - SPX Standardized Options (PUT)                                           -0.164094
# OptionMetrics - SPX Strike Price, Currently Alw...                                       -0.213678
# OptionMetrics - SPX Theta of the Option (CALL)                                            1.000000
# OptionMetrics - SPX VegaKappa of the Option (PUT)                                        -0.578260
# CRSP Daily Stock Market Indexes - Level of the ...                                        0.078059
#
#                                                     OptionMetrics - SPX VegaKappa of the Option (PUT)  \
# CBOE DJIA Volatility Index                                                                  -0.083562
# CBOE NASDAQ Volatility Index                                                                -0.117744
# CBOE S&P100 Volatility Index                                                                -0.103215
# CBOE S&P500 Volatility Index                                                                -0.089026
# OptionMetrics - DJI Historical Volatility                                                   -0.094360
# OptionMetrics - Russell 2000 Historical Volatility                                          -0.094752
# OptionMetrics - SPX Historical Volatility                                                   -0.067324
# OptionMetrics - DJX  Index Dividend Yield                                                   -0.007301
# OptionMetrics - Russell 2000  Index Dividend Yield                                           0.037388
# OptionMetrics - SPX  Index Dividend Yield                                                    0.041050
# OptionMetrics - Russel 2000 The total contract ...                                          -0.034741
# OptionMetrics - Russel 2000 Option Volume                                                   -0.057039
# OptionMetrics - DJX Option Volume                                                           -0.120355
# OptionMetrics - DJX The total contract open int...                                          -0.150541
# OptionMetrics - SPX Option Volume                                                           -0.076648
# OptionMetrics - SPX The total contract open int...                                           0.039146
# OptionMetrics - DJX Calculated Price for the Un...                                           0.127071
# OptionMetrics - DJX Delta of the Option(CALL)                                                0.134074
# OptionMetrics - DJX Implied Volatility of the O...                                           0.020048
# OptionMetrics - DJX Interpolated Premium for th...                                           0.245104
# OptionMetrics - DJX Strike Price, Currently Alw...                                           0.046299
# OptionMetrics - DJX Theta of the Option(CALL)                                               -0.225448
# OptionMetrics - DJX VegaKappa of the Option(CALL)                                            0.254520
# OptionMetrics - Zero Coupon Yield Curve                                                      0.265307
# OptionMetrics - DJX Calculated Price for the Un...                                           0.127071
# OptionMetrics - DJX Delta of the Option (PUT)                                               -0.125339
# OptionMetrics - DJX Gamma of the Option (PUT)                                               -0.208350
# OptionMetrics - DJX Interpolated Premium for th...                                           0.263393
# OptionMetrics - DJX Strike Price, Currently Alw...                                           0.046299
# OptionMetrics - DJX Theta of the Option (PUT)                                               -0.189129
# OptionMetrics - DJX VegaKappa of the Option (PUT)                                            0.254465
# OptionMetrics - Russell 2000 Calculated Price f...                                           0.149946
# OptionMetrics - Russell 2000 Delta of the Optio...                                           0.092407
# OptionMetrics - Russell 2000 Gamma of the Optio...                                          -0.088997
# OptionMetrics - Russell 2000 Implied Volatility...                                          -0.019527
# OptionMetrics - Russell 2000 Interpolated Premi...                                           0.154882
# OptionMetrics - Russell 2000 Strike Price, Curr...                                           0.129571
# OptionMetrics - Russell 2000 Theta of the Optio...                                          -0.103641
# OptionMetrics - Russell 2000 VegaKappa of the O...                                           0.150707
# OptionMetrics - Russell 2000 VegaKappa of the O...                                           0.150713
# OptionMetrics - Russell 2000 Theta of the Optio...                                          -0.123562
# OptionMetrics - Russell 2000 Gamma of the Optio...                                          -0.095947
# OptionMetrics - Russell 2000 Delta of the Optio...                                          -0.098092
# OptionMetrics - Russell 2000 Implied Volatility...                                          -0.015533
# OptionMetrics - Russell 2000 Interpolated Premi...                                           0.163381
# OptionMetrics - Russell 2000 Strike Price, Curr...                                           0.129571
# OptionMetrics - Russell 2000 Calculated Price f...                                           0.149946
# OptionMetrics - SPX Calculated Price for the Un...                                           0.107766
# OptionMetrics - SPX Delta of the Option (CALL)                                               0.755665
# OptionMetrics - SPX Gamma of the Option (CALL)                                              -0.597607
# OptionMetrics - SPX Implied Volatility of the O...                                           0.262409
# OptionMetrics - SPX Interpolated Premium for th...                                           0.931936
# OptionMetrics - SPX Standardized Options (PUT)                                               0.107766
# OptionMetrics - SPX Strike Price, Currently Alw...                                           0.264837
# OptionMetrics - SPX Theta of the Option (CALL)                                              -0.578260
# OptionMetrics - SPX VegaKappa of the Option (PUT)                                            1.000000
# CRSP Daily Stock Market Indexes - Level of the ...                                           0.054181
#
#                                                     CRSP Daily Stock Market Indexes - Level of the S&P 500 Index
# CBOE DJIA Volatility Index                                                                  -0.032132
# CBOE NASDAQ Volatility Index                                                                -0.015777
# CBOE S&P100 Volatility Index                                                                -0.018350
# CBOE S&P500 Volatility Index                                                                -0.023454
# OptionMetrics - DJI Historical Volatility                                                   -0.031404
# OptionMetrics - Russell 2000 Historical Volatility                                          -0.004509
# OptionMetrics - SPX Historical Volatility                                                   -0.021322
# OptionMetrics - DJX  Index Dividend Yield                                                   -0.017889
# OptionMetrics - Russell 2000  Index Dividend Yield                                          -0.046761
# OptionMetrics - SPX  Index Dividend Yield                                                   -0.063261
# OptionMetrics - Russel 2000 The total contract ...                                           0.080111
# OptionMetrics - Russel 2000 Option Volume                                                   -0.053041
# OptionMetrics - DJX Option Volume                                                            0.019114
# OptionMetrics - DJX The total contract open int...                                           0.003569
# OptionMetrics - SPX Option Volume                                                           -0.028502
# OptionMetrics - SPX The total contract open int...                                           0.046000
# OptionMetrics - DJX Calculated Price for the Un...                                           0.109587
# OptionMetrics - DJX Delta of the Option(CALL)                                                0.007586
# OptionMetrics - DJX Implied Volatility of the O...                                          -0.022193
# OptionMetrics - DJX Interpolated Premium for th...                                           0.009762
# OptionMetrics - DJX Strike Price, Currently Alw...                                          -0.004274
# OptionMetrics - DJX Theta of the Option(CALL)                                               -0.031623
# OptionMetrics - DJX VegaKappa of the Option(CALL)                                            0.043647
# OptionMetrics - Zero Coupon Yield Curve                                                      0.129982
# OptionMetrics - DJX Calculated Price for the Un...                                           0.109587
# OptionMetrics - DJX Delta of the Option (PUT)                                               -0.031930
# OptionMetrics - DJX Gamma of the Option (PUT)                                                0.026206
# OptionMetrics - DJX Interpolated Premium for th...                                           0.030327
# OptionMetrics - DJX Strike Price, Currently Alw...                                          -0.004274
# OptionMetrics - DJX Theta of the Option (PUT)                                               -0.054329
# OptionMetrics - DJX VegaKappa of the Option (PUT)                                            0.043595
# OptionMetrics - Russell 2000 Calculated Price f...                                           0.079881
# OptionMetrics - Russell 2000 Delta of the Optio...                                          -0.016727
# OptionMetrics - Russell 2000 Gamma of the Optio...                                           0.122429
# OptionMetrics - Russell 2000 Implied Volatility...                                          -0.036135
# OptionMetrics - Russell 2000 Interpolated Premi...                                           0.227849
# OptionMetrics - Russell 2000 Strike Price, Curr...                                           0.188857
# OptionMetrics - Russell 2000 Theta of the Optio...                                           0.098332
# OptionMetrics - Russell 2000 VegaKappa of the O...                                           0.162223
# OptionMetrics - Russell 2000 VegaKappa of the O...                                           0.162245
# OptionMetrics - Russell 2000 Theta of the Optio...                                           0.057123
# OptionMetrics - Russell 2000 Gamma of the Optio...                                           0.119367
# OptionMetrics - Russell 2000 Delta of the Optio...                                          -0.007211
# OptionMetrics - Russell 2000 Implied Volatility...                                          -0.034653
# OptionMetrics - Russell 2000 Interpolated Premi...                                           0.228755
# OptionMetrics - Russell 2000 Strike Price, Curr...                                           0.188857
# OptionMetrics - Russell 2000 Calculated Price f...                                           0.079881
# OptionMetrics - SPX Calculated Price for the Un...                                           0.107884
# OptionMetrics - SPX Delta of the Option (CALL)                                              -0.006699
# OptionMetrics - SPX Gamma of the Option (CALL)                                               0.082694
# OptionMetrics - SPX Implied Volatility of the O...                                          -0.017209
# OptionMetrics - SPX Interpolated Premium for th...                                           0.116763
# OptionMetrics - SPX Standardized Options (PUT)                                               0.107884
# OptionMetrics - SPX Strike Price, Currently Alw...                                           0.286594
# OptionMetrics - SPX Theta of the Option (CALL)                                               0.078059
# OptionMetrics - SPX VegaKappa of the Option (PUT)                                            0.054181
# CRSP Daily Stock Market Indexes - Level of the ...                                           1.000000

# %%
# 1. Recursive Feature Elimination (RFE) for Regression
model = LinearRegression()
rfe = RFE(model, n_features_to_select=5)
fit = rfe.fit(train_data, index_train_data.values.ravel())
selected_features_rfe = train_data.columns[fit.support_]
print('use RFE')
print("Num Features:", fit.n_features_)
print("Selected Features:", selected_features_rfe)
print("Feature Ranking:", fit.ranking_)
# Out:
# use RFE
# Num Features: 5
# Selected Features: Index(['OptionMetrics - DJX VegaKappa of the Option(CALL)',
#        'OptionMetrics - DJX VegaKappa of the Option (PUT)',
#        'OptionMetrics - Russell 2000 Delta of the Option(CALL)',
#        'OptionMetrics - Russell 2000 VegaKappa of the Option(CALL)',
#        'OptionMetrics - Russell 2000 VegaKappa of the Option (PUT)'],
#       dtype='object')
# Feature Ranking: [ 5  9  4 39 34 50 33 27  7 28 30 44 52 31 46 45 49  3 21 38 47 43  1 35
#  48 17 22 37 40 20  1 41  1 14  8 15 16 18  1  1 19 13  2 32 11 29 42 26
#   6 51 23 25 12 10 36 24]

# %%
# 2. Feature Importance from RandomForest
# If it's regression:
forest = RandomForestRegressor(n_estimators=100)
# If it's classification:
# forest = RandomForestClassifier(n_estimators=100)

forest.fit(train_data, index_train_data.values.ravel())
importances = forest.feature_importances_
indices = np.argsort(importances)[::-1]
print("RandomForest: Feature ranking:")
for f in range(train_data.shape[1]):
    print("%d. Feature %s (%f)" % (f + 1, train_data.columns[indices[f]], importances[indices[f]]))
# Out:
# RandomForest: Feature ranking:
# 1. Feature OptionMetrics - SPX Strike Price, Currently Always Equal to Forward Price (CALL) (0.214309)
# 2. Feature OptionMetrics - Zero Coupon Yield Curve (0.061133)
# 3. Feature OptionMetrics - Russell 2000 Strike Price, Currently Always Equal to Forward Price (CALL) (0.044176)
# 4. Feature OptionMetrics - Russell 2000 Strike Price, Currently Always Equal to Forward Price (PUT) (0.036339)
# 5. Feature OptionMetrics - Russel 2000 The total contract open interest (0.028172)
# 6. Feature OptionMetrics - DJX The total contract open interest (0.026221)
# 7. Feature OptionMetrics - SPX Implied Volatility of the Option (CALL) (0.022200)
# 8. Feature OptionMetrics - DJX Option Volume (0.020746)
# 9. Feature OptionMetrics - SPX Delta of the Option (CALL) (0.020447)
# 10. Feature OptionMetrics - Russell 2000  Index Dividend Yield (0.020091)
# 11. Feature OptionMetrics - SPX Calculated Price for the Underlying Security on the Exp. Date (CALL) (0.019982)
# 12. Feature OptionMetrics - SPX The total contract open interest (0.019661)
# 13. Feature OptionMetrics - DJX  Index Dividend Yield (0.018939)
# 14. Feature OptionMetrics - Russell 2000 Calculated Price for the Underlying Security on the Exp. Date (CALL) (0.017752)
# 15. Feature OptionMetrics - DJX Strike Price, Currently Always Equal to Forward Price (PUT) (0.017715)
# 16. Feature OptionMetrics - SPX Standardized Options (PUT) (0.017309)
# 17. Feature OptionMetrics - DJX Calculated Price for the Underlying Security on the Exp. Date (CALL) (0.017261)
# 18. Feature OptionMetrics - DJX Delta of the Option(CALL) (0.016849)
# 19. Feature OptionMetrics - DJX Strike Price, Currently Always Equal to Forward Price(CALL) (0.016117)
# 20. Feature OptionMetrics - DJX Theta of the Option (PUT) (0.014552)
# 21. Feature OptionMetrics - SPX  Index Dividend Yield (0.014246)
# 22. Feature OptionMetrics - DJX Theta of the Option(CALL) (0.014062)
# 23. Feature OptionMetrics - Russel 2000 Option Volume (0.013206)
# 24. Feature OptionMetrics - Russell 2000 Calculated Price for the Underlying Security on the Exp. Date (PUT) (0.012725)
# 25. Feature OptionMetrics - DJX Calculated Price for the Underlying Security on the Exp. Date (PUT).xlsx (0.012676)
# 26. Feature OptionMetrics - Russell 2000 Interpolated Premium for the Option (CALL) (0.012564)
# 27. Feature OptionMetrics - Russell 2000 Implied Volatility of the Option(CALL) (0.012320)
# 28. Feature OptionMetrics - Russell 2000 Theta of the Option(CALL) (0.012319)
# 29. Feature OptionMetrics - SPX Historical Volatility (0.012263)
# 30. Feature OptionMetrics - Russell 2000 Historical Volatility (0.011566)
# 31. Feature CBOE NASDAQ Volatility Index (0.011497)
# 32. Feature OptionMetrics - DJX Interpolated Premium for the Option(CALL) (0.010650)
# 33. Feature OptionMetrics - Russell 2000 VegaKappa of the Option(CALL) (0.010624)
# 34. Feature OptionMetrics - SPX Option Volume (0.010359)
# 35. Feature OptionMetrics - Russell 2000 Theta of the Option (PUT) (0.010105)
# 36. Feature OptionMetrics - Russell 2000 Implied Volatility of the Option (PUT) (0.010074)
# 37. Feature CBOE S&P100 Volatility Index (0.009810)
# 38. Feature CBOE S&P500 Volatility Index (0.009480)
# 39. Feature OptionMetrics - DJX Implied Volatility of the Option(CALL) (0.009361)
# 40. Feature OptionMetrics - Russell 2000 Delta of the Option (PUT) (0.009234)
# 41. Feature OptionMetrics - Russell 2000 Interpolated Premium for the Option (PUT) (0.008793)
# 42. Feature OptionMetrics - DJI Historical Volatility (0.008674)
# 43. Feature OptionMetrics - Russell 2000 VegaKappa of the Option (PUT) (0.008296)
# 44. Feature OptionMetrics - SPX VegaKappa of the Option (PUT) (0.007904)
# 45. Feature OptionMetrics - SPX Theta of the Option (CALL) (0.007154)
# 46. Feature OptionMetrics - Russell 2000 Gamma of the Option(CALL) (0.006966)
# 47. Feature OptionMetrics - Russell 2000 Gamma of the Option (PUT) (0.006868)
# 48. Feature OptionMetrics - SPX Interpolated Premium for the Option (CALL) (0.006606)
# 49. Feature OptionMetrics - DJX VegaKappa of the Option(CALL) (0.006485)
# 50. Feature OptionMetrics - Russell 2000 Delta of the Option(CALL) (0.005833)
# 51. Feature OptionMetrics - DJX Delta of the Option (PUT) (0.005251)
# 52. Feature OptionMetrics - DJX VegaKappa of the Option (PUT) (0.005106)
# 53. Feature CBOE DJIA Volatility Index (0.005001)
# 54. Feature OptionMetrics - DJX Interpolated Premium for the Option (PUT) (0.004992)
# 55. Feature OptionMetrics - DJX Gamma of the Option (PUT) (0.004169)
# 56. Feature OptionMetrics - SPX Gamma of the Option (CALL) (0.002786)

# %%
# 3. Univariate Selection using SelectKBest
print('use Univariate Selection using SelectKBest')
test = SelectKBest(score_func=f_classif, k=5)
fit = test.fit(train_data, index_train_data.values.ravel())
selected_features_skb = train_data.columns[fit.get_support()]
print("Selected Features:", selected_features_skb)
# Out:
# use Univariate Selection using SelectKBest
# Selected Features: Index(['OptionMetrics - SPX Interpolated Premium for the Option (CALL)',
#        'OptionMetrics - SPX Standardized Options (PUT)',
#        'OptionMetrics - SPX Strike Price, Currently Always Equal to Forward Price (CALL)',
#        'OptionMetrics - SPX Theta of the Option (CALL)',
#        'OptionMetrics - SPX VegaKappa of the Option (PUT)'],
#       dtype='object')
