# %% [markdown]
# #World Quant University
# ###MScFE Capstone Project
#
# ####Nabil Mohammed Khamis
# (mkhamisnabil@gmail.com)
#
# ##MARGET REGIME CLASSIFICATION FOR SWING TRADING

# %%
#GaussianHMM is imported from hmmlearn forming the basis of the model. 
#Matplotlib and Seaborn are imported to plot the in-sample hidden states, necessary for a "sanity check" 
#on the models behaviour
import pandas_datareader as web
from pandas_datareader import data
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib import cm
from matplotlib.dates import YearLocator, MonthLocator
# %matplotlib inline
import pandas as pd
from sklearn import metrics
from hmmlearn import hmm
import numpy as np
import seaborn as sns
import missingno as msno
from tqdm import tqdm
import statsmodels as sm
from statsmodels.tsa.stattools import adfuller
import math
import backtrader as bt
import pyfolio as pf
p=print
# Out:
# /Users/raymondli/miniconda3/lib/python3.10/site-packages/pyfolio/pos.py:26: UserWarning: Module "zipline.assets" not found; mutltipliers will not be applied to position notionals.
#   warnings.warn(

# %% [markdown]
# Hidden Markov Models are a type of stochastic state-space model. They assume the existence of "hidden" or "latent" states that are not directly observable. These hidden states have an influence on values which are observable, known as the observations. One of the goals of the model is to ascertain the current state from the set of known observations.
#
# Asset returns are observations that are indirectly influenced by the hidden market regimes. Fitting a Hidden Markov Model to the underlying asset returns data permits prediction of new regime states, which can be used us regime filters for risk managment

# %%
# Define the instruments to download. We would like to see Apple, Microsoft and the S&P500 index.
tickers = ['AAPL', 'MSFT', '^GSPC', 'FB', 'AAL', 'INTC' ]

# get observable variables including interest rate spread data from federal reserve data 
#and asset from yahoo finance for underlying asset returns

f1 = 'TEDRATE' # ted spread
f2 = 'T10Y2Y' # 10yr minus 2yr treasury constant maturity 
f3 = 'T10Y3M' #  10yr minus 3months treasury constant maturity

# We would like all available data from 01/01/2000 to date.
start_date = pd.to_datetime('2000-01-01')
end_date = pd.datetime.today()
#
# Use pandas_reader.data.DataReader to load the desired data. As simple as that.
stk = 'AAPL'
STK = (web.DataReader([stk], 'yahoo', start_date, end_date)['Adj Close']
       .rename(columns={stk:stk})
       .assign(sret=lambda x: np.log(x[stk]/x[stk].shift(1)))
       .dropna())

data = (web.DataReader([f1, f2, f3], 'fred', start_date, end_date)
        .join(STK, how='inner')
        .dropna()
       )

p(data.head())

# gives us a quick visual inspection of the data
#msno.matrix(data)
# Out:
# /var/folders/1s/hjk6vgwx413bb0gvk7wfl_z40000gn/T/ipykernel_25934/1401834278.py:13: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   end_date = pd.datetime.today()
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 17
#      14 #
#      15 # Use pandas_reader.data.DataReader to load the desired data. As simple as that.
#      16 stk = 'AAPL'
# ---> 17 STK = (web.DataReader([stk], 'yahoo', start_date, end_date)['Adj Close']
#      18        .rename(columns={stk:stk})
#      19        .assign(sret=lambda x: np.log(x[stk]/x[stk].shift(1)))
#      20        .dropna())
#      22 data = (web.DataReader([f1, f2, f3], 'fred', start_date, end_date)
#      23         .join(STK, how='inner')
#      24         .dropna()
#      25        )
#      27 p(data.head())
#
# ...

# %% [markdown]
# https://blog.quantinsti.com/trading-using-machine-learning-python/
#
# http://www.blackarbs.com/blog/introduction-hidden-markov-models-python-networkx-sklearn/2/9/2017

# %%
# code adapted from http://hmmlearn.readthedocs.io
# for sklearn 18.1

col = 'sret'
select = data.iloc[:].dropna()

ft_cols = [f1, f2, f3, 'sret']
X = select[ft_cols].values

#A GaussianHMM to be fit it requires a specific number of states through the n_components parameter. 
#A full covariance matrix is used and the number of iterations used in the 
#Expectation-Maximisation algorithm is given by the n_iter parameter.


model = hmm.GaussianHMM(n_components=3, covariance_type="full", n_iter=1000)
model = model.fit(X)


# Predict the optimal sequence of internal hidden state
hidden_states = model.predict(X)

print("Means and vars of each hidden state")
for i in range(model.n_components):
    print("{0}th hidden state".format(i))
    print("mean = ", model.means_[i])
    print("var = ", np.diag(model.covars_[i]))
    print()

#The hidden states masking the adjusted closing prices are plotted
sns.set(font_scale=1.25)
style_kwds = {'xtick.major.size': 3, 'ytick.major.size': 3,
              'font.family':u'courier prime code', 'legend.frameon': True}
sns.set_style('white', style_kwds)

fig, axs = plt.subplots(model.n_components, sharex=True, sharey=True, figsize=(12,9))
colors = cm.rainbow(np.linspace(0, 1, model.n_components))

for i, (ax, color) in enumerate(zip(axs, colors)):
    # Use fancy indexing to plot data in each state.
    mask = hidden_states == i
    ax.plot_date(select.index.values[mask],
                 select[col].values[mask],
                 ".-", c=color)
    ax.set_title("{0}th hidden state".format(i), fontsize=16, fontweight='demi')

    # Format the ticks.
    ax.xaxis.set_major_locator(YearLocator())
    ax.xaxis.set_minor_locator(MonthLocator())
    sns.despine(offset=10)

plt.tight_layout()
fig.savefig('Hidden Markov Model_Regime Subplots.png')
# Out:
# Means and vars of each hidden state
# 0th hidden state
# mean =  [0.41831787 0.16604489 0.35429554 0.00108258]
# var =  [0.03833325 0.08261944 0.32411044 0.00068037]
#
# 1th hidden state
# mean =  [2.42239297e-01 1.89682123e+00 2.47434027e+00 1.19207231e-03]
# var =  [5.04315287e-03 3.07289057e-01 4.92106460e-01 3.96575615e-04]
#
# 2th hidden state
# mean =  [ 9.88539160e-01  1.33829683e+00  1.75121621e+00 -5.79204953e-04]
# var =  [0.42590423 0.40250768 0.95312105 0.00175084]
# findfont: Font family ['courier prime code'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['courier prime code'] not found. Falling back to DejaVu Sans.

# %%
 print("Model Score:", model.score(X))
# Out:
# Model Score: 10248.975664067222

# %%
sns.set(font_scale=1.5)
states = (pd.DataFrame(hidden_states, columns=['states'], index=select.index)
          .join(select, how='inner')
          .assign(mkt_cret=select.sret.cumsum())
          .reset_index(drop=False)
          .rename(columns={'index':'Date'}))
p(states.head())

sns.set_style('white', style_kwds)
order = [0, 1, 2]
fg = sns.FacetGrid(data=states, hue='states', hue_order=order,
                   palette=None, aspect=1.31, size=12)
fg.map(plt.scatter, 'Date', stk, alpha=0.8).add_legend()
sns.despine(offset=10)
fg.fig.suptitle('Historical AAPL Regimes', fontsize=24, fontweight='demi')
fg.savefig('Hidden Markov Model_AAPL Regimes.png')
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/axisgrid.py:316: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# findfont: Font family ['courier prime code'] not found. Falling back to DejaVu Sans.
#         Date  states  TEDRATE  T10Y2Y  T10Y3M      AAPL      sret  mkt_cret
# 0 2000-01-04       0     0.77    0.19    1.06  0.790842 -0.088078 -0.088078
# 1 2000-01-05       0     0.75    0.24    1.18  0.802415  0.014528 -0.073550
# 2 2000-01-06       0     0.78    0.22    1.16  0.732975 -0.090514 -0.164064
# 3 2000-01-07       0     0.81    0.21    1.14  0.767695  0.046281 -0.117783
# 4 2000-01-10       0     0.79    0.19    1.15  0.754193 -0.017745 -0.135528
# findfont: Font family ['courier prime code'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['courier prime code'] not found. Falling back to DejaVu Sans.

# %%
for i in order:
    print('Mean for regime %i: '%i,model.means_[i][0])
    print('Co-Variance for regime %i: '%i,model.covars_[i])
# Out:
# Mean for regime 0:  0.41831787342792154
# Co-Variance for regime 0:  [[ 3.83332512e-02 -3.29647233e-02 -1.68079242e-02 -1.50765262e-04]
#  [-3.29647233e-02  8.26194395e-02  1.23020931e-01  1.77651982e-04]
#  [-1.68079242e-02  1.23020931e-01  3.24110443e-01  1.09019942e-04]
#  [-1.50765262e-04  1.77651982e-04  1.09019942e-04  6.80365285e-04]]
# Mean for regime 1:  0.2422392965221742
# Co-Variance for regime 1:  [[ 5.04315287e-03 -2.32917233e-02 -2.62570066e-02 -3.24193128e-05]
#  [-2.32917233e-02  3.07289057e-01  3.40316435e-01  2.27541951e-04]
#  [-2.62570066e-02  3.40316435e-01  4.92106460e-01  3.40490314e-04]
#  [-3.24193128e-05  2.27541951e-04  3.40490314e-04  3.96575615e-04]]
# Mean for regime 2:  0.9885391602140033
# Co-Variance for regime 2:  [[ 4.25904229e-01  5.95953699e-02  1.24796632e-01 -4.25859769e-04]
#  [ 5.95953699e-02  4.02507683e-01  5.80457017e-01  5.39895398e-04]
#  [ 1.24796632e-01  5.80457017e-01  9.53121049e-01  1.08221033e-03]
# ...

# %% [markdown]
# ##AAPL
# ###Regime 0:High mean with Lowest Covariance (Bullish)
# ###Regime 1:Least mean with Highest Covariance (Bearish)
# ###Regime 2:Neutral mean with medium Covariance(Neutral)

# %%
# Iterate through the three states
for i in range(0,3):
    states['sret'][states['states'] == i]
    
    # Draw the density plot
    sns.distplot(states['sret'][states['states'] == i], hist = False, kde = True,
                 kde_kws = {'linewidth': 3},
                 label = states)
    print (str(i) + ": " + str(round((states['sret'][states['states'] == i]).mean()*100,3))+"%")
plt.legend([0,1,2])
fig.suptitle('AAPL Returns Distribution', fontsize=24, fontweight='demi')
# Out:
# 0: 0.11%
# 1: 0.118%
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
for i in range(0,3):
    (states['sret'][states['states'] == i]).hist()
    print (str(i) + ": " + str(round((states['sret'][states['states'] == i]).mean()*100,3))+"%")
plt.legend([0,1,2])
fig.suptitle('AAPL Returns Distribution', fontsize=24, fontweight='demi')
# Out:
# 0: 0.11%
# 1: 0.118%
# 2: -0.057%
# Text(0.5, 0.98, 'AAPL Returns Distribution')

# %%
#We call the asset for backtesting with our selectec trading strategies
df = web.DataReader('AAPL', 'yahoo', start_date, end_date)
df['Return']= np.log(df['Adj Close']/df['Adj Close'].shift(1))
df['Returns_std'] = df['Return'].rolling(100).std()
df['SMA'] = df['Return'].rolling(100).mean()
df = df.dropna()

# %% [markdown]
# # **Trading Strategies**
#
# We use the backtrader backtesting framework to backtest our strategies

# %% [markdown]
# ###Moving Average Crossover Strategy
#
# In this strategy, we use two exponential moving averages with a short and long timeframe, so go long when the fast moving average crosses over the slow moving average and short when the slow moving average crosses over the fast moving average. We therefore hold a position at anytime, when one trade closes, a trade in the opposite direction is taken.

# %%
class MovingAverageCrossoverStrategy(bt.Strategy):
    
    lines = ('SlowEMA', 'FastEMA', 'trail_price')
    
    def log(self, txt, dt=None):
        ''' Logging function for this strategy'''
        dt = dt or self.datas[0].datetime.datetime(0)
        print('%s, %s' % (dt.strftime("%Y-%m-%d %H:%M"), txt))    
    
    def __init__(self):
        
        self.FastEMA = bt.indicators.ExponentialMovingAverage(self.datas[0], period=50)
        self.SlowEMA = bt.indicators.ExponentialMovingAverage(self.datas[0], period=200)
        
        self.crup = bt.ind.CrossUp(self.FastEMA, self.SlowEMA)
        self.crdown = bt.ind.CrossUp(self.SlowEMA,self.FastEMA)
        
        
        # To keep track of pending orders and buy price/commission
        self.order = None
        self.buyprice = None
        self.buycomm = None
        
    def notify_order(self, order):
        
        if order.status in [order.Submitted, order.Accepted]:
            # Buy/Sell order submitted/accepted to/by broker - Nothing to do
            return

        # Check if an order has been completed
        # Attention: broker could reject order if not enough cash
        if order.status in [order.Completed]:
            if order.isbuy():
                self.log(
                    'BUY EXECUTED, Price: %.2f, Cost: %.2f, Comm %.2f' %
                    (order.executed.price,
                     order.executed.value,
                     order.executed.comm))

                self.buyprice = order.executed.price
                self.buycomm = order.executed.comm
                
            else:  # Sell
                self.log('SELL EXECUTED, Price: %.2f, Cost: %.2f, Comm %.2f' %
                         (order.executed.price,
                          order.executed.value,
                          order.executed.comm))

            self.bar_executed = len(self)

        elif order.status in [order.Canceled, order.Margin, order.Rejected]:
            self.log('Order Canceled/Margin/Rejected')

        self.order = None
        
        
    def notify_trade(self, trade):
        if not trade.isclosed:
            return

        self.log('OPERATION PROFIT, GROSS %.2f, NET %.2f' %
                 (trade.pnl, trade.pnlcomm))
        
    def next(self):
        
        
        # Check if an order is pending ... if yes, we cannot send a 2nd one
        if self.order:
            return
        
        # Check if we are in the market
        if not self.position:
        
        # Not yet ... we MIGHT BUY if ...
            if self.crup[0] == 1:
                self.log('BUY CREATE, %.2f' % self.data.close[0])
                self.order = self.buy(price=self.data.close[0])
                    
            elif self.crdown[0] == -1:
                self.log('SHORT CREATE, %.2f' % self.data.close[0])
                self.order = self.sell(price=self.data.close[0])
                    
        else:

            # Already in the market ... we might sell
            if self.crdown[0] == -1:
                self.log('SELL CREATE, %.2f' % self.data.close[0])
                self.order = self.sell()
                self.order = self.sell(price=self.data.close[0], exectype=bt.Order.StopTrail, trailpercent=0.01)
                
            elif self.crup[0] == 1:
                self.log('LONG COVER CREATE, %.2f' % self.data.close[0])
                self.order = self.buy()
                self.order = self.buy(price=self.data.close[0], exectype=bt.Order.StopTrail, trailpercent=0.01)  
                              
 
#Cerebro is backtrader's core engine 

if __name__ == '__main__':

    cerebro = bt.Cerebro()

    # Add a strategy
    cerebro.addstrategy(MovingAverageCrossoverStrategy)
    
    # Analyzer
    cerebro.addanalyzer(bt.analyzers.SharpeRatio, _name='mysharpe')
    cerebro.addanalyzer(bt.analyzers.PyFolio)
    
    # Create a Data Feed
    data = bt.feeds.PandasData(dataname=df)
    
    # Add the Data Feed to Cerebro
    cerebro.adddata(data)
    
    # Add a FixedSize sizer according to the stake
    cerebro.addsizer(bt.sizers.PercentSizer, percents=10)
    
    # Set the commission for 0.1%
    cerebro.broker.setcommission(commission=0.001)
    
    print('Starting Portfolio Value: %.2f' % cerebro.broker.getvalue())
    SR = cerebro.run()
    print('Final Portfolio Value: %.2f' % cerebro.broker.getvalue())
    
    # Plot the result
    cerebro.plot()


    SR1 = SR[0]
    
    print(" ")
    print('Sharpe Ratio:', SR1.analyzers.mysharpe.get_analysis())
    
    pyfoliozer = SR1.analyzers.getbyname('pyfolio')
    returns, positions, transactions, gross_lev = pyfoliozer.get_pf_items()
# Out:
# Starting Portfolio Value: 10000.00
# 2002-02-05 00:00, BUY CREATE, 0.45
# 2002-02-06 00:00, BUY EXECUTED, Price: 0.46, Cost: 1005.89, Comm 1.01
# 2003-05-23 00:00, LONG COVER CREATE, 0.33
# 2003-05-27 00:00, BUY EXECUTED, Price: 0.32, Cost: 705.70, Comm 0.71
# 2003-05-27 00:00, BUY EXECUTED, Price: 0.33, Cost: 727.04, Comm 0.73
# 2006-08-03 00:00, LONG COVER CREATE, 2.49
# 2006-08-04 00:00, Order Canceled/Margin/Rejected
# 2006-08-04 00:00, Order Canceled/Margin/Rejected
# 2008-04-16 00:00, LONG COVER CREATE, 5.49
# 2008-04-17 00:00, Order Canceled/Margin/Rejected
# 2008-04-17 00:00, Order Canceled/Margin/Rejected
# 2009-05-11 00:00, LONG COVER CREATE, 4.63
# 2009-05-12 00:00, Order Canceled/Margin/Rejected
# 2009-05-12 00:00, Order Canceled/Margin/Rejected
# 2013-10-03 00:00, LONG COVER CREATE, 17.26
# 2013-10-04 00:00, Order Canceled/Margin/Rejected
# 2013-10-04 00:00, Order Canceled/Margin/Rejected
# 2016-08-31 00:00, LONG COVER CREATE, 26.52
# ...

# %% [markdown]
# ##Simple Moving Average
#
# In this stratefy, we enter a long position when the market closes above a simple moving average and exits when the market closes below the moving average.

# %%
class MovingAverageStrategy(bt.Strategy):
    
    lines = ('SlowEMA', 'FastEMA',)
    
    def log(self, txt, dt=None):
        ''' Logging function for this strategy'''
        dt = dt or self.datas[0].datetime.datetime(0)
        print('%s, %s' % (dt.strftime("%Y-%m-%d %H:%M"), txt))    
    
    def __init__(self):
        
        self.FastEMA = bt.indicators.ExponentialMovingAverage(self.datas[0], period=50)
        self.SlowEMA = bt.indicators.ExponentialMovingAverage(self.datas[0], period=200)
        
        # To keep track of pending orders and buy price/commission
        self.order = None
        self.buyprice = None
        self.buycomm = None
        
    def notify_order(self, order):
        
        if order.status in [order.Submitted, order.Accepted]:
            # Buy/Sell order submitted/accepted to/by broker - Nothing to do
            return

        # Check if an order has been completed
        # Attention: broker could reject order if not enough cash
        if order.status in [order.Completed]:
            if order.isbuy():
                self.log(
                    'BUY EXECUTED, Price: %.2f, Cost: %.2f, Comm %.2f' %
                    (order.executed.price,
                     order.executed.value,
                     order.executed.comm))

                self.buyprice = order.executed.price
                self.buycomm = order.executed.comm
            else:  # Sell
                self.log('SELL EXECUTED, Price: %.2f, Cost: %.2f, Comm %.2f' %
                         (order.executed.price,
                          order.executed.value,
                          order.executed.comm))

            self.bar_executed = len(self)

        elif order.status in [order.Canceled, order.Margin, order.Rejected]:
            self.log('Order Canceled/Margin/Rejected')

        self.order = None
        
    def notify_trade(self, trade):
        if not trade.isclosed:
            return

        self.log('OPERATION PROFIT, GROSS %.2f, NET %.2f' %
                 (trade.pnl, trade.pnlcomm))
        
    def next(self):
        
        
        # Check if an order is pending ... if yes, we cannot send a 2nd one
        if self.order:
            return
        
        # Check if we are in the market
        if not self.position:
        
        # Not yet ... we MIGHT BUY if ...
            if self.FastEMA[0] > self.SlowEMA[0]:
                    self.log('BUY CREATE, %.2f' % self.data.close[0])
                    self.order = self.buy()
                
        else:

            # Already in the market ... we might sell
            if self.FastEMA[0] < self.SlowEMA[0]:
                self.log('SELL CREATE, %.2f' % self.data.close[0])
                self.order = self.sell()

                
        
if __name__ == '__main__':

    cerebro = bt.Cerebro()

    # Add a strategy
    cerebro.addstrategy(MovingAverageStrategy)
    
    # Analyzer
    cerebro.addanalyzer(bt.analyzers.SharpeRatio, _name='mysharpe')
    cerebro.addanalyzer(bt.analyzers.PyFolio)
    
    # Create a Data Feed
    data = bt.feeds.PandasData(dataname=df)
    
    # Add the Data Feed to Cerebro
    cerebro.adddata(data)
    
    # Add a FixedSize sizer according to the stake
    cerebro.addsizer(bt.sizers.PercentSizer, percents=10)
    
    # Set the commission for 0.1%
    cerebro.broker.setcommission(commission=0.001)
    
    print('Starting Portfolio Value: %.2f' % cerebro.broker.getvalue())
    SR = cerebro.run()
    print('Final Portfolio Value: %.2f' % cerebro.broker.getvalue())
    
    # Plot the result
    cerebro.plot()


    SR1 = SR[0]
    
    print(" ")
    print('Sharpe Ratio:', SR1.analyzers.mysharpe.get_analysis())
    
    pyfoliozer = SR1.analyzers.getbyname('pyfolio')
    returns, positions, transactions, gross_lev = pyfoliozer.get_pf_items()
# Out:
# Starting Portfolio Value: 10000.00
# 2002-02-05 00:00, BUY CREATE, 0.45
# 2002-02-06 00:00, BUY EXECUTED, Price: 0.46, Cost: 1005.89, Comm 1.01
# 2002-06-18 00:00, SELL CREATE, 0.36
# 2002-06-19 00:00, SELL EXECUTED, Price: 0.31, Cost: 1005.89, Comm 0.68
# 2002-06-19 00:00, OPERATION PROFIT, GROSS -323.38, NET -325.07
# 2003-05-23 00:00, BUY CREATE, 0.33
# 2003-05-27 00:00, BUY EXECUTED, Price: 0.32, Cost: 948.48, Comm 0.95
# 2006-07-06 00:00, SELL CREATE, 1.99
# 2006-07-07 00:00, SELL EXECUTED, Price: 1.98, Cost: 948.48, Comm 5.86
# 2006-07-07 00:00, OPERATION PROFIT, GROSS 4911.40, NET 4904.59
# 2006-08-03 00:00, BUY CREATE, 2.49
# 2006-08-04 00:00, BUY EXECUTED, Price: 2.39, Cost: 1404.74, Comm 1.40
# 2008-02-29 00:00, SELL CREATE, 4.47
# 2008-03-03 00:00, SELL EXECUTED, Price: 4.44, Cost: 1404.74, Comm 2.61
# 2008-03-03 00:00, OPERATION PROFIT, GROSS 1202.36, NET 1198.34
# 2008-04-16 00:00, BUY CREATE, 5.49
# 2008-04-17 00:00, BUY EXECUTED, Price: 5.51, Cost: 1582.61, Comm 1.58
# ...

# %%
# Pyfolio tearsheet is called to efficiently evaluate the performance of our strategies
#Warning is given due an attribute of pyfolio which is not handled by numpy
pf.create_full_tear_sheet(returns)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2000-05-25</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2020-10-26</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>244</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>4.7%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>156.9%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>6.2%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>0.78</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>0.26</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.91</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-18.4%</td>
#     </tr>
#     <tr>
# ...
